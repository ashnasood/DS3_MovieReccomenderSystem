# %% [markdown]
# # **Movies Dataset Content-Based, Collaborative Filtering, and Hybrid Recommender Models and Demo of Hybrid Recommender Model with 3 User Profiles**

# %% [markdown]
# ## **Collaborators**
# - Ashna Sood
# - Urmi Suresh
# - Tae Kim
# - Xianglong Wang

# %% [markdown]
# ## **Imports**

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
import os 
import pickle
import math

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats

from sklearn.metrics import make_scorer, accuracy_score, plot_confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, GridSearchCV
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.manifold import TSNE

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

from nltk.stem.snowball import SnowballStemmer

from sklearn import metrics

# %% [markdown]
# ## **Content Based Recommender System Using Cleaned Metadata**

# %%
# read in cleaned movies metadata csv file
movies_df = pd.read_csv("movies_metadata_cleaned.csv")
movies_df
# Out:
#                ID    IMDB ID              Title               Collection  \
# 0          461257  tt6980792           Queerama                      NaN
# 1           92323  tt0081758    Willie and Phil                      NaN
# 2          114838  tt0029949        Brother Rat                      NaN
# 3          264723  tt0070580         Le pélican                      NaN
# 4           88061  tt0055459  So Evil, So Young                      NaN
# ...           ...        ...                ...                      ...
# 42273       24428  tt0848228       The Avengers    theavengerscollection
# 42274       19995  tt0499549             Avatar         avatarcollection
# 42275         155  tt0468569    The Dark Knight  thedarkknightcollection
# 42276       27205  tt1375666          Inception                      NaN
# 42277  2014-01-01          0                NaN                      NaN
#
#                                                   Genres Language  \
# 0                                                     []       en
# 1                                                     []       en
# 2                                             ['Comedy']       en
# 3                                                     []       en
# 4                                              ['Drama']       en
# ...                                                  ...      ...
# 42273         ['Science Fiction', 'Action', 'Adventure']       en
# 42274  ['Action', 'Adventure', 'Fantasy', 'Science Fi...       en
# 42275           ['Drama', 'Action', 'Crime', 'Thriller']       en
# 42276  ['Action', 'Thriller', 'Science Fiction', 'Mys...       en
# 42277  ['Odyssey Media', 'Pulser Productions', 'Rogue...     82.0
#
#       Spoken Languages Release Date  Runtime       Revenue  ...  \
# 0               ['en']   2017-06-09     75.0           NaN  ...
# 1                   []   1980-08-15    115.0           NaN  ...
# 2               ['en']   1938-10-29     87.0           NaN  ...
# 3                   []   1974-02-06     83.0           NaN  ...
# 4               ['en']   1963-01-01     77.0           NaN  ...
# ...                ...          ...      ...           ...  ...
# 42273           ['en']   2012-04-25    143.0  1.519558e+09  ...
# 42274     ['en', 'es']   2009-12-10    162.0  2.787965e+09  ...
# 42275     ['en', 'zh']   2008-07-16    152.0  1.004558e+09  ...
# 42276           ['en']   2010-07-14    148.0  8.255328e+08  ...
# 42277               []          NaN      NaN           NaN  ...
#
#                                  Production Countries Popularity Rating  \
# 0                                  ['United Kingdom']          0.163015
# 1                                                  []          0.326500
# 2                        ['United States of America']          0.174691
# 3                                                  []          0.000115
# 4                                                  []          0.001662
# ...                                               ...               ...
# 42273                    ['United States of America']         89.887648
# 42274  ['United States of America', 'United Kingdom']        185.070892
# 42275  ['United Kingdom', 'United States of America']        123.167259
# 42276  ['United Kingdom', 'United States of America']         29.108149
# 42277                                             NaN               NaN
#
#        Vote Count  Vote Average  \
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ...           ...           ...
# 42273     12000.0           7.4
# 42274     12114.0           7.2
# 42275     12269.0           8.3
# 42276     14075.0           8.1
# 42277         NaN           NaN
#
#                                                 Keywords  \
# 0                                                     []
# 1                                                     []
# 2                               ['basedonplayormusical']
# 3                                                     []
# 4                            ['prison', "women'sprison"]
# ...                                                  ...
# 42273  ['newyork', 'shield', 'marvelcomic', 'superher...
# 42274  ['cultureclash', 'future', 'spacewar', 'spacec...
# 42275  ['dccomics', 'crimefighter', 'secretidentity',...
# 42276  ['lossoflover', 'dream', 'kidnapping', 'sleep'...
# 42277                                                 []
#
#                                                     Cast          Director  \
# 0                                                     []      daisyasquith
# 1       ['michaelontkean', 'raysharkey', 'margotkidder']      paulmazursky
# 2      ['ronaldreagan', 'janewyman', 'priscillalane',...   williamkeighley
# 3                                                     []       gérardblain
# 4      ['jillireland', 'ellenpollock', 'joanhaythorne...    godfreygrayson
# ...                                                  ...               ...
# 42273  ['robertdowneyjr.', 'chrisevans', 'markruffalo...        josswhedon
# 42274  ['samworthington', 'zoesaldana', 'sigourneywea...      jamescameron
# 42275  ['christianbale', 'michaelcaine', 'heathledger...  christophernolan
# 42276  ['leonardodicaprio', 'josephgordon-levitt', 'e...  christophernolan
# 42277                                                 []               NaN
#
#                  Writer          Producer  \
# 0                   NaN               NaN
# 1          paulmazursky               NaN
# 2             jerrywald               NaN
# 3                   NaN               NaN
# 4          markgrantham               NaN
# ...                 ...               ...
# 42273        josswhedon           stanlee
# 42274      jamescameron      jamescameron
# 42275  christophernolan      charlesroven
# 42276  christophernolan  christophernolan
# 42277               NaN               NaN
#
#                                                 Metadata
# 0                                        daisyasquith
# 1      paulmazursky paulmazursky  michaelontkean rays...
# 2      williamkeighley jerrywald  Comedy ronaldreagan...
# 3                                         gérardblain
# 4      godfreygrayson markgrantham  Drama jillireland...
# ...                                                  ...
# 42273  josswhedon josswhedon stanlee theavengerscolle...
# 42274  jamescameron jamescameron jamescameron avatarc...
# 42275  christophernolan christophernolan charlesroven...
# 42276  christophernolan christophernolan christophern...
# 42277     Odyssey Media Pulser Productions Rogue Stat...
#
# [42278 rows x 21 columns]

# %% [markdown]
# Content based recommendation systems use specific features of items to produce recommendations of other items that are similar to what a user has already indicated that they like. The user provided data is usually explicitly expressed via a rating the user has previously given, or implicitly expressed via clicking on a link. For our recommendation system, the specific features of the items that we wanted to use to produce recommendations was something we created ourselves using the features that were given to us in the original movies dataset. This was our metadata. We then created a cosine similarity matrix using a TF-IDF table of every pair of words in each one of the movies’ metadata strings. We decided on the cosine similarity matrix after exploring other options such as the Euclidean Distance and Pearson Correlation, as the cosine similarity is efficient at comparing how similar the contents of two vectors is and is minimally affected by what the magnitudes of the vectors are. Our output for each movie inputted was 20 movies with the highest similarity score.

# %%
# vectorize the movies' metadata
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
# tokenizes the strings and returns a vector for each string 
count_matrix = count.fit_transform(movies_df["Metadata"])

# calculate cosine similarity between the movies
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# save cosine similarity matrix 
outfile = "metadata_cosineSim"
np.save(outfile, cosine_sim)

# %%
# load metadata cosine similarity matrix 
cosine_sim_loaded = np.load("metadata_cosineSim.npy")

# %%
movies_df = movies_df.reset_index()
movie_titles = movies_df['Title']
indices = pd.Series(movies_df.index, index=movies_df['Title'])

# %% [markdown]
# Content Based recommender method to extract movie recommendations based on input movie title.

# %%
# method concept inspired from kaggle notebook 
def get_recommendations(movie_title):
    movie_index = indices[movie_title]
    sim_scores = list(enumerate(cosine_sim_loaded[movie_index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:20]
    movie_indices = [i[0] for i in sim_scores]
    return list(movie_titles.iloc[movie_indices])

# %% [markdown]
# ## **Collaborative Filtering**

# %%
# !pip install scikit-surprise
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
from surprise import dump
# Out:
# Requirement already satisfied: scikit-surprise in /home/ashna/anaconda3/lib/python3.8/site-packages (1.1.1)
# Requirement already satisfied: six>=1.10.0 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (0.16.0)
# Requirement already satisfied: scipy>=1.0.0 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (1.5.0)
# Requirement already satisfied: numpy>=1.11.2 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (1.19.5)

# %%
# read in movie ratings 
ratings_df = pd.read_csv('Movies Data/ratings.csv')

# rename columns
ratings_df = ratings_df.rename(columns={"userId": "User ID", 
                                        "movieId": "Movie ID", 
                                        "timestamp": "Timestamp"})

# %%
ratings_df
# Out:
#           User ID  Movie ID  rating   Timestamp
# 0               1       110     1.0  1425941529
# 1               1       147     4.5  1425942435
# 2               1       858     5.0  1425941523
# 3               1      1221     5.0  1425941546
# 4               1      1246     5.0  1425941556
# ...           ...       ...     ...         ...
# 26024284   270896     58559     5.0  1257031564
# 26024285   270896     60069     5.0  1257032032
# 26024286   270896     63082     4.5  1257031764
# 26024287   270896     64957     4.5  1257033990
# 26024288   270896     71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
# check for null values
ratings_df.isnull().any()
# Out:
# User ID      False
# Movie ID     False
# rating       False
# Timestamp    False
# dtype: bool

# %% [markdown]
# Collaborative filtering is an algorithm that creates recommendations based on data collected from other users, using the assumption that users who have similar interests in certain items are more likely to see eye to eye again. This stems from the idea that if we have friends who share our similar interests, then we would trust their recommendations in the future simply because we think we have the same tastes. Our collaborative filtering algorithm uses the similarity index technique where a certain number of users are chosen based on how similar they are to the user we are focusing on. The algorithm to calculate this is Signular Value Decompositon (SVD), which is a matrix factorization technique that reduces the number of features of a dataset. In the context of collaborative filtering, each row is a user and each column is a movie item, and the values in the matrix are the user ratings.  Then a weighted average of the selected users is created and that number provides the suggestions for the focused user.

# %%
reader = Reader()

# %%
data = Dataset.load_from_df(ratings_df[['User ID', 'Movie ID', 'rating']], reader)
algo = SVD()
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.7965  0.7962  0.7956  0.7962  0.7960  0.7961  0.0003
# MAE (testset)     0.6023  0.6025  0.6019  0.6023  0.6021  0.6022  0.0002
# Fit time          685.16  694.63  693.42  692.81  695.55  692.31  3.70
# Test time         57.71   58.90   49.77   49.97   46.38   52.54   4.88
# {'test_rmse': array([0.79654272, 0.79619573, 0.79561253, 0.79622099, 0.79598232]),
#  'test_mae': array([0.60225976, 0.60245458, 0.60187422, 0.6023217 , 0.6021279 ]),
#  'fit_time': (685.1593697071075,
#   694.6251404285431,
#   693.4244229793549,
#   692.8122618198395,
#   695.5460493564606),
#  'test_time': (57.705753564834595,
#   58.895099401474,
#   49.7657413482666,
#   49.96788167953491,
#   46.383798360824585)}

# %%
training_data = data.build_full_trainset()
algo.fit(training_data)

# %% [markdown]
# Surprise package predict method takes in:
# - uid = user ID
# - iid = item id
# - rui = true rating -- optional

# %%
algo.predict(1, 302, 3).est

# %%
# Dump algorithm to save 
file_name = "SVD_model_ex"
dump.dump(file_name, algo=algo)

# %% [markdown]
# ### Reload Collaboraitve Filtering Model

# %%
# reload algorithm
from surprise import dump
file_name = "SVD_model_ex"
_, loaded_algo = dump.load(file_name)

# %% [markdown]
# ## Hybrid Recommender combining Content Based and Collaborative Filtering Models

# %% [markdown]
# **Hybrid Recommender combining content based model and collaborative filtering model. Going to input the User ID and title of the movie and return top 20 movies that are similar based on both the metadata of the input movie and the user's preferences and predicted ratings of those movies.**

# %%
movies_df
# Out:
#        index          ID    IMDB ID              Title  \
# 0          0      461257  tt6980792           Queerama
# 1          1       92323  tt0081758    Willie and Phil
# 2          2      114838  tt0029949        Brother Rat
# 3          3      264723  tt0070580         Le pélican
# 4          4       88061  tt0055459  So Evil, So Young
# ...      ...         ...        ...                ...
# 42273  42273       24428  tt0848228       The Avengers
# 42274  42274       19995  tt0499549             Avatar
# 42275  42275         155  tt0468569    The Dark Knight
# 42276  42276       27205  tt1375666          Inception
# 42277  42277  2014-01-01          0                NaN
#
#                     Collection  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 42273    theavengerscollection
# 42274         avatarcollection
# 42275  thedarkknightcollection
# 42276                      NaN
# 42277                      NaN
#
#                                                   Genres Language  \
# 0                                                     []       en
# 1                                                     []       en
# 2                                             ['Comedy']       en
# 3                                                     []       en
# 4                                              ['Drama']       en
# ...                                                  ...      ...
# 42273         ['Science Fiction', 'Action', 'Adventure']       en
# 42274  ['Action', 'Adventure', 'Fantasy', 'Science Fi...       en
# 42275           ['Drama', 'Action', 'Crime', 'Thriller']       en
# 42276  ['Action', 'Thriller', 'Science Fiction', 'Mys...       en
# 42277  ['Odyssey Media', 'Pulser Productions', 'Rogue...     82.0
#
#       Spoken Languages Release Date  Runtime  ...  \
# 0               ['en']   2017-06-09     75.0  ...
# 1                   []   1980-08-15    115.0  ...
# 2               ['en']   1938-10-29     87.0  ...
# 3                   []   1974-02-06     83.0  ...
# 4               ['en']   1963-01-01     77.0  ...
# ...                ...          ...      ...  ...
# 42273           ['en']   2012-04-25    143.0  ...
# 42274     ['en', 'es']   2009-12-10    162.0  ...
# 42275     ['en', 'zh']   2008-07-16    152.0  ...
# 42276           ['en']   2010-07-14    148.0  ...
# 42277               []          NaN      NaN  ...
#
#                                  Production Countries Popularity Rating  \
# 0                                  ['United Kingdom']          0.163015
# 1                                                  []          0.326500
# 2                        ['United States of America']          0.174691
# 3                                                  []          0.000115
# 4                                                  []          0.001662
# ...                                               ...               ...
# 42273                    ['United States of America']         89.887648
# 42274  ['United States of America', 'United Kingdom']        185.070892
# 42275  ['United Kingdom', 'United States of America']        123.167259
# 42276  ['United Kingdom', 'United States of America']         29.108149
# 42277                                             NaN               NaN
#
#       Vote Count  Vote Average  \
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ...          ...           ...
# 42273    12000.0           7.4
# 42274    12114.0           7.2
# 42275    12269.0           8.3
# 42276    14075.0           8.1
# 42277        NaN           NaN
#
#                                                 Keywords  \
# 0                                                     []
# 1                                                     []
# 2                               ['basedonplayormusical']
# 3                                                     []
# 4                            ['prison', "women'sprison"]
# ...                                                  ...
# 42273  ['newyork', 'shield', 'marvelcomic', 'superher...
# 42274  ['cultureclash', 'future', 'spacewar', 'spacec...
# 42275  ['dccomics', 'crimefighter', 'secretidentity',...
# 42276  ['lossoflover', 'dream', 'kidnapping', 'sleep'...
# 42277                                                 []
#
#                                                     Cast          Director  \
# 0                                                     []      daisyasquith
# 1       ['michaelontkean', 'raysharkey', 'margotkidder']      paulmazursky
# 2      ['ronaldreagan', 'janewyman', 'priscillalane',...   williamkeighley
# 3                                                     []       gérardblain
# 4      ['jillireland', 'ellenpollock', 'joanhaythorne...    godfreygrayson
# ...                                                  ...               ...
# 42273  ['robertdowneyjr.', 'chrisevans', 'markruffalo...        josswhedon
# 42274  ['samworthington', 'zoesaldana', 'sigourneywea...      jamescameron
# 42275  ['christianbale', 'michaelcaine', 'heathledger...  christophernolan
# 42276  ['leonardodicaprio', 'josephgordon-levitt', 'e...  christophernolan
# 42277                                                 []               NaN
#
#                  Writer          Producer  \
# 0                   NaN               NaN
# 1          paulmazursky               NaN
# 2             jerrywald               NaN
# 3                   NaN               NaN
# 4          markgrantham               NaN
# ...                 ...               ...
# 42273        josswhedon           stanlee
# 42274      jamescameron      jamescameron
# 42275  christophernolan      charlesroven
# 42276  christophernolan  christophernolan
# 42277               NaN               NaN
#
#                                                 Metadata
# 0                                        daisyasquith
# 1      paulmazursky paulmazursky  michaelontkean rays...
# 2      williamkeighley jerrywald  Comedy ronaldreagan...
# 3                                         gérardblain
# 4      godfreygrayson markgrantham  Drama jillireland...
# ...                                                  ...
# 42273  josswhedon josswhedon stanlee theavengerscolle...
# 42274  jamescameron jamescameron jamescameron avatarc...
# 42275  christophernolan christophernolan charlesroven...
# 42276  christophernolan christophernolan christophern...
# 42277     Odyssey Media Pulser Productions Rogue Stat...
#
# [42278 rows x 22 columns]

# %%
# read in movies ID map csv file
movies_ID_map = pd.read_csv("movies_ID_map.csv")
movies_ID_map
# Out:
#                    Title      ID  Movie ID
# 0               Queerama  461257    176279
# 1        Willie and Phil   92323    112577
# 2            Brother Rat  114838    112548
# 3             Le pélican  264723    112510
# 4      So Evil, So Young   88061    112467
# ...                  ...     ...       ...
# 42272           Deadpool  293660    122904
# 42273       The Avengers   24428     89745
# 42274             Avatar   19995     72998
# 42275    The Dark Knight     155     58559
# 42276          Inception   27205     79132
#
# [42277 rows x 3 columns]

# %% [markdown]
# We chose to ultimately create a Hybrid Recommender Model that combined the content based model and collaborative filtering model because we wanted to create a recommender that used both the user’s past preferences as well as other user’s preferences who were similar to the active user. To do this our initial goal was to input the User ID and title of the movie we wanted similar movies for and to output the top 20 movies that were similar to the input movie based on both the metadata of the input movie and the user’s preferences and predicted ratings of those movies. Thus, the movies that are recommended from this hybrid model are not only preferenced by similar movie features but also a predicted higher rating that the user would give to that movie.

# %%
# method that produces recommendations based off of both metadata and user preferences
def hybrid_recommender(userID, title):
    index = indices[title]
    tmdbId = movies_ID_map.loc[movies_ID_map["Title"] == title]['ID']
    movie_id = movies_ID_map.loc[movies_ID_map["Title"] == title]['Movie ID']
    
    # take top 20 movies based on similarity scores to calculate the vote of the 60th percentile movie
    # then calculate the weighted rating of each movie using IMDB formula 
    sim_scores = list(enumerate(cosine_sim_loaded[int(index)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:21]
    similar_movie_indices = [i[0] for i in sim_scores]
    
    movies = movies_df.iloc[similar_movie_indices][['Title', 'Vote Count', 'Vote Average', 'ID']]
    similar_movies_IDs = list(map(int, movies["ID"].values))

    for ID, index in zip(similar_movies_IDs, similar_movie_indices):
        movieID = int(movies_ID_map.loc[movies_ID_map["ID"] == ID]['Movie ID'])
        est_rating = loaded_algo.predict(userID, movieID).est
        movies.loc[index, "est"] = est_rating
        
    movies = movies.sort_values('est', ascending=False)
    return movies

# %% [markdown]
# Basic Testing of the Hybrid Recommender Comparing between User 10 and User 35

# %%
hybrid_recommender(10, 'The Avengers')
# Out:
#                                                Title  Vote Count  \
# 42262                                       Iron Man      8951.0
# 36165                                      Team Thor        93.0
# 41411                                       Serenity      1287.0
# 42248                     Captain America: Civil War      7462.0
# 42272                                       Deadpool     11444.0
# 32729          Marvel Studios: Assembling a Universe        44.0
# 42263                                     Iron Man 3      8951.0
# 42206                                 Doctor Strange      5880.0
# 42207            Captain America: The Winter Soldier      5881.0
# 42243             Captain America: The First Avenger      7174.0
# 42216                                        Ant-Man      6029.0
# 42240                        Avengers: Age of Ultron      6908.0
# 42001                            The Incredible Hulk      3086.0
# 42241                                     Iron Man 2      6969.0
# 42168                           Thor: The Dark World      4873.0
# 36848                       Marvel One-Shot: Item 47       114.0
# 42235                                           Thor      6678.0
# 33212                 Iron Man & Hulk: Heroes United        48.0
# 34903  Avengers Confidential: Black Widow & Punisher        68.0
# 27752      Iron Man & Captain America: Heroes United        21.0
#
#        Vote Average      ID       est
# 42262           7.4    1726  4.358564
# 36165           7.5  413279  4.226156
# 41411           7.4   16320  4.225701
# 42248           7.1  271110  4.222177
# 42272           7.4  293660  4.203255
# 32729           6.6  259910  4.160966
# 42263           6.8   68721  4.054722
# 42206           7.1  284052  4.051236
# 42207           7.6  100402  4.002187
# 42243           6.6    1771  3.992446
# 42216           7.0  102899  3.972867
# 42240           7.3   99861  3.968228
# 42001           6.1    1724  3.954245
# 42241           6.6   10138  3.935198
# 42168           6.8   76338  3.858243
# 36848           6.6  119569  3.851223
# 42235           6.6   10195  3.842486
# 33212           5.4  230896  3.569638
# 34903           5.8  257346  3.461510
# 27752           5.8  284274  3.367549

# %%
hybrid_recommender(35, 'The Avengers')
# Out:
#                                                Title  Vote Count  \
# 41411                                       Serenity      1287.0
# 42206                                 Doctor Strange      5880.0
# 42262                                       Iron Man      8951.0
# 36165                                      Team Thor        93.0
# 32729          Marvel Studios: Assembling a Universe        44.0
# 42248                     Captain America: Civil War      7462.0
# 42272                                       Deadpool     11444.0
# 42216                                        Ant-Man      6029.0
# 42207            Captain America: The Winter Soldier      5881.0
# 42240                        Avengers: Age of Ultron      6908.0
# 36848                       Marvel One-Shot: Item 47       114.0
# 42243             Captain America: The First Avenger      7174.0
# 42241                                     Iron Man 2      6969.0
# 42235                                           Thor      6678.0
# 42263                                     Iron Man 3      8951.0
# 42001                            The Incredible Hulk      3086.0
# 42168                           Thor: The Dark World      4873.0
# 27752      Iron Man & Captain America: Heroes United        21.0
# 34903  Avengers Confidential: Black Widow & Punisher        68.0
# 33212                 Iron Man & Hulk: Heroes United        48.0
#
#        Vote Average      ID       est
# 41411           7.4   16320  4.361905
# 42206           7.1  284052  4.153873
# 42262           7.4    1726  4.126833
# 36165           7.5  413279  4.112717
# 32729           6.6  259910  4.099205
# 42248           7.1  271110  4.091808
# 42272           7.4  293660  4.054944
# 42216           7.0  102899  4.043048
# 42207           7.6  100402  3.992822
# 42240           7.3   99861  3.966149
# 36848           6.6  119569  3.920767
# 42243           6.6    1771  3.892130
# 42241           6.6   10138  3.747923
# 42235           6.6   10195  3.678164
# 42263           6.8   68721  3.662126
# 42001           6.1    1724  3.603179
# 42168           6.8   76338  3.560764
# 27752           5.8  284274  3.469509
# 34903           5.8  257346  3.275457
# 33212           5.4  230896  3.271672

# %%
hybrid_recommender(10, 'Mean Girls')
# Out:
#                                                    Title  Vote Count  \
# 31692  Puella Magi Madoka Magica the Movie Part III: ...        36.0
# 14299                                Live from New York!         5.0
# 34656                               Just One of the Guys        64.0
# 38215                                      Geek Charming       188.0
# 28333                                         Screwballs        22.0
# 35695                                          Frenemies        83.0
# 39125                              It's a Boy Girl Thing       279.0
# 37231                                             Zapped       131.0
# 41469                                           The DUFF      1372.0
# 35992                                  The Cheetah Girls        90.0
# 35099                          How to Build a Better Boy        71.0
# 39792                        Princess Protection Program       381.0
# 41234                               The Princess Diaries      1063.0
# 41069                                      Freaky Friday       919.0
# 38430                            I Love You, Beth Cooper       204.0
# 36564                                          Sleepover       105.0
# 41020                                            Beastly       878.0
# 35681                                     Barbie Diaries        83.0
# 40115            American Pie Presents: The Book of Love       454.0
# 39137                                       Mean Girls 2       281.0
#
#        Vote Average      ID       est
# 31692           7.3  212162  4.394826
# 14299           5.4  334328  3.755567
# 34656           6.4   24548  3.754710
# 38215           6.0   81250  3.725091
# 28333           4.7   25164  3.665975
# 35695           5.2   84105  3.548348
# 39125           6.3   37725  3.443764
# 37231           5.6  278774  3.432579
# 41469           6.8  272693  3.397726
# 35992           4.9   32293  3.391446
# 35099           5.7  286987  3.348946
# 39792           6.2   19458  3.341236
# 41234           6.5    9880  3.297944
# 41069           6.0   10330  3.262167
# 38430           5.2   19840  3.181469
# 36564           5.4    9893  3.007504
# 41020           5.9   38117  2.905606
# 35681           5.5   21705  2.898022
# 40115           5.1   26123  2.680548
# 39137           5.1   51481  2.313185

# %%
hybrid_recommender(35, 'Mean Girls')
# Out:
#                                                    Title  Vote Count  \
# 31692  Puella Magi Madoka Magica the Movie Part III: ...        36.0
# 14299                                Live from New York!         5.0
# 35695                                          Frenemies        83.0
# 39125                              It's a Boy Girl Thing       279.0
# 34656                               Just One of the Guys        64.0
# 38215                                      Geek Charming       188.0
# 35099                          How to Build a Better Boy        71.0
# 28333                                         Screwballs        22.0
# 37231                                             Zapped       131.0
# 41469                                           The DUFF      1372.0
# 41069                                      Freaky Friday       919.0
# 41234                               The Princess Diaries      1063.0
# 35992                                  The Cheetah Girls        90.0
# 39792                        Princess Protection Program       381.0
# 35681                                     Barbie Diaries        83.0
# 38430                            I Love You, Beth Cooper       204.0
# 36564                                          Sleepover       105.0
# 41020                                            Beastly       878.0
# 39137                                       Mean Girls 2       281.0
# 40115            American Pie Presents: The Book of Love       454.0
#
#        Vote Average      ID       est
# 31692           7.3  212162  4.404914
# 14299           5.4  334328  3.952208
# 35695           5.2   84105  3.521542
# 39125           6.3   37725  3.472875
# 34656           6.4   24548  3.401603
# 38215           6.0   81250  3.387064
# 35099           5.7  286987  3.364189
# 28333           4.7   25164  3.328902
# 37231           5.6  278774  3.312382
# 41469           6.8  272693  3.311737
# 41069           6.0   10330  3.238174
# 41234           6.5    9880  3.169254
# 35992           4.9   32293  3.118925
# 39792           6.2   19458  3.114169
# 35681           5.5   21705  3.025963
# 38430           5.2   19840  2.991909
# 36564           5.4    9893  2.938378
# 41020           5.9   38117  2.822588
# 39137           5.1   51481  2.448561
# 40115           5.1   26123  2.403273

# %% [markdown]
# ## Demo of Hybrid Recommender System

# %% [markdown]
# In order to showcase the efficacy of our hybrid recommender system, we will be displaying the recommended movies and results of 3 different user profiles based on various movies they liked/disliked:
#
# Movie Name (Movie ID) - User Rating

# %% [markdown]
# **User 1 -- Romantic Comedies Movies Fanatic:**
#
# User Rated movies:
# 1. He’s Just Not That Into You (66203) - 4.5
# 2. The Proposal (69406) - 5.0
# 3. Bridget Jones’ Diary (4246) - 5.0
# 4. 13 Going on 30 (7444) - 4.0
# 5. What a Girl Wants (6266) - 3.5
# 6. The Great Kidnapping (118510) - 1.5
# 7. My Favorite Blonde (25884) - 3.0
# 8. Being Ginger (151371) - 2.0
# 9. The Blind Sunflowers (88652)- 1.0
# 10. The Avengers (89745) - 3.5
#
# The movies that will be fed into the model to see the results are:
#
# a. My Big Fat Greek Wedding
#
# b. Father of the Bride

# %% [markdown]
# **User 2 -- Action Movies Fanatic:**
#
# User Rated movies:
# 1. The Avengers (89745) - 5.0
# 2. Captain America (26764) - 5.0
# 3. Mission: Impossible (648) - 4.5
# 4. National Treasure (8972) - 3.5
# 5. Skyfall (96079) - 4.0
# 6. Senseless (1746) - 1.0
# 7. Get Over It (4168) - 2.5
# 8. Moana (166461) - 1.5
# 9. La La Land (164909) - 0.5
# 10. Divergent (108190) - 3.0
#
# The movies that will be fed into the model to see the results are:
#
# a. Die Hard
#
# b. Lethal Weapon

# %% [markdown]
# **User 3 -- Bollywood Movies Fanatic:**
#
# User Rated movies:
# 1. Zindagi Na Milegi Dobara (89554) - 5.0
# 2. Rab Ne Bana Di Jodi (64650) - 5.0
# 3. Dhoom (107707) - 4.5
# 4. Om Shanti Om (56167) - 5.0
# 5. Main Hoon Na (36083) - 4.5
# 6. Bigfoot (103869) - 2.0
# 7. Road to Paloma (143637) - 3.0
# 8. Rocket Singh: Salesman of the Year (94661) - 1.5
# 9. Hansel and Gretel (125401) - 1.0
# 10. The Boy and the Pirates (107157) - 0.5
#
# The movies that will be fed into the model to see the results are:
#
# a. Dilwale Dulhania Le Jayenge
#
# b. Kabhi Khushi Kabhie Gham

# %% [markdown]
# In order for the model to work, we will be incorporating the user's ratings of each movies to create a user profile to add to our current dataset in order to produce user-based recommendations.

# %%
ratings_df
# Out:
#           User ID  Movie ID  rating   Timestamp
# 0               1       110     1.0  1425941529
# 1               1       147     4.5  1425942435
# 2               1       858     5.0  1425941523
# 3               1      1221     5.0  1425941546
# 4               1      1246     5.0  1425941556
# ...           ...       ...     ...         ...
# 26024284   270896     58559     5.0  1257031564
# 26024285   270896     60069     5.0  1257032032
# 26024286   270896     63082     4.5  1257031764
# 26024287   270896     64957     4.5  1257033990
# 26024288   270896     71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
# method to add user ratings for movies to the ratings_df 
def add_user_rating(df, user_ID, movie_ID, rating, timestamp=1257031858):
    df.loc[len(df.index)] = [user_ID, movie_ID, rating, timestamp]

# %%
# user 270897 ratings 
user_270897 = [270897, 270897, 270897, 270897, 270897, 270897, 270897, 270897, 270897, 270897]
movie_IDs_270897 = [66203, 69406, 4246, 7444, 6266, 118510, 25884, 151371, 88652, 89745]
ratings_270897 = [4.5, 5.0, 5.0, 4.0, 3.5, 1.5, 3.0, 2.0, 1.0, 3.0]

# add user ratings to ratings_df
for user_ID, movie_ID, rating in zip(user_270897, movie_IDs_270897, ratings_270897):
    add_user_rating(ratings_df, user_ID, movie_ID, rating)
    
# user 270898 ratings 
user_270898 = [270898, 270898, 270898, 270898, 270898, 270898, 270898, 270898, 270898, 270898]
movie_IDs_270898 = [89745, 26764, 648, 8972, 96079, 1746, 4168, 166461, 164909, 108190]
ratings_270898 = [5.0, 5.0, 4.5, 3.5, 4.0, 1.0, 2.5, 1.5, 0.5, 3.0]

# add user ratings to ratings_df
for user_ID, movie_ID, rating in zip(user_270898, movie_IDs_270898, ratings_270898):
    add_user_rating(ratings_df, user_ID, movie_ID, rating)
    
# user 270899 ratings 
user_270899 = [270899, 270899, 270899, 270899, 270899, 270899, 270899, 270899, 270899, 270899]
movie_IDs_270899 = [89554, 64650, 107707, 56167, 36083, 103869, 143637, 94661, 125401, 107157]
ratings_270899 = [5.0, 5.0, 4.5, 5.0, 4.5, 2.0, 3.0, 1.5, 1.0, 0.5]

# add user ratings to ratings_df
for user_ID, movie_ID, rating in zip(user_270899, movie_IDs_270899, ratings_270899):
    add_user_rating(ratings_df, user_ID, movie_ID, rating)

ratings_df
# Out:
#            User ID  Movie ID  rating     Timestamp
# 0              1.0     110.0     1.0  1.425942e+09
# 1              1.0     147.0     4.5  1.425942e+09
# 2              1.0     858.0     5.0  1.425942e+09
# 3              1.0    1221.0     5.0  1.425942e+09
# 4              1.0    1246.0     5.0  1.425942e+09
# ...            ...       ...     ...           ...
# 26024314  270899.0  103869.0     2.0  1.257032e+09
# 26024315  270899.0  143637.0     3.0  1.257032e+09
# 26024316  270899.0   94661.0     1.5  1.257032e+09
# 26024317  270899.0  125401.0     1.0  1.257032e+09
# 26024318  270899.0  107157.0     0.5  1.257032e+09
#
# [26024319 rows x 4 columns]

# %%
reader = Reader()

# %%
data = Dataset.load_from_df(ratings_df[['User ID', 'Movie ID', 'rating']], reader)
algo = SVD()
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.7958  0.7958  0.7952  0.7962  0.7960  0.7958  0.0004
# MAE (testset)     0.6018  0.6018  0.6015  0.6020  0.6020  0.6018  0.0002
# Fit time          683.28  695.24  696.22  695.18  688.76  691.74  4.99
# Test time         60.27   57.21   51.74   57.78   57.82   56.97   2.82
# {'test_rmse': array([0.79580782, 0.79579842, 0.79515564, 0.79620523, 0.79598913]),
#  'test_mae': array([0.60175944, 0.60179018, 0.60148886, 0.60201913, 0.60203228]),
#  'fit_time': (683.2793922424316,
#   695.2398734092712,
#   696.2245357036591,
#   695.1762704849243,
#   688.7601597309113),
#  'test_time': (60.27135252952576,
#   57.21423673629761,
#   51.74291276931763,
#   57.77811813354492,
#   57.81974959373474)}

# %%
training_data = data.build_full_trainset()
algo.fit(training_data)

# %%
# Dump algorithm to save 
file_name = "SVD_model_demo"
dump.dump(file_name, algo=algo)

# %% [markdown]
# #### Reload SVD demo

# %%
# reload algorithm
from surprise import dump
file_name = "SVD_model_demo"
_, loaded_algo_demo = dump.load(file_name)

# %%
# testing new SVD model with added user profiles
user1_pred1 = loaded_algo_demo.predict(270897, 302, 3)
rating1 = user1_pred1.est
rating1
# Out:
# 3.6565093784809406

# %%
# modified method with demo svd model and user friendly output
# method that produces recommendations based off of both metadata and user preferences
def hybrid_recommender(userID, title):
    index = indices[title]
    tmdbId = movies_ID_map.loc[movies_ID_map["Title"] == title]['ID']
    movie_id = movies_ID_map.loc[movies_ID_map["Title"] == title]['Movie ID']
    
    # take top 20 movies based on similarity scores to calculate the vote of the 60th percentile movie
    # then calculate the weighted rating of each movie using IMDB formula 
    sim_scores = list(enumerate(cosine_sim_loaded[int(index)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:21]
    similar_movie_indices = [i[0] for i in sim_scores]
    
    movies = movies_df.iloc[similar_movie_indices][['Title', 'Vote Count', 'Vote Average', 'ID']]
    similar_movies_IDs = list(map(int, movies["ID"].values))

    for ID, index in zip(similar_movies_IDs, similar_movie_indices):
        movieID = int(movies_ID_map.loc[movies_ID_map["ID"] == ID]['Movie ID'])
        est_rating = loaded_algo_demo.predict(userID, movieID).est
        movies.loc[index, "est"] = est_rating
        
    movies = movies.sort_values('est', ascending=False)
    return list(movies["Title"]), movies

# %% [markdown]
# **User 1 (270897) - Romantic Comedies Movies Fanatic:**

# %%
# User 1 (270897) Movie Recc 1: My Big Fat Greek Wedding
u1_recc_titles1, u1_recc_movies1 = hybrid_recommender(270897, "My Big Fat Greek Wedding")
print("Hybrid Recommender Suggested Movies: \n", u1_recc_titles1)
u1_recc_movies1
# Out:
# Hybrid Recommender Suggested Movies:
#  ['The Big City', 'Father of the Bride', 'Brothers', 'Meet the Fockers', 'Days of Wine and Roses', 'The Front Page', 'Make Way for Tomorrow', 'The Wedding', 'Junebug', 'Guess Who', 'Herbstmilch', 'Aşk Kırmızı', 'Julia Misbehaves', 'The Ref', 'Lawyer Man', 'Five Nights in Maine', 'Monster-in-Law', "I Hate Valentine's Day", 'Over the Top', 'Date Movie']
#                         Title  Vote Count  Vote Average      ID       est
# 25303            The Big City        16.0           8.0   60567  3.924296
# 39630     Father of the Bride       355.0           6.2   11846  3.753976
# 40640                Brothers       650.0           6.8    7445  3.633077
# 41491        Meet the Fockers      1412.0           6.1     693  3.591512
# 32124  Days of Wine and Roses        39.0           7.5   32488  3.566119
# 34932          The Front Page        69.0           6.9     987  3.512676
# 31768   Make Way for Tomorrow        37.0           7.7   41059  3.487779
# 16918             The Wedding         7.0           6.6   10819  3.459577
# 34768                 Junebug        66.0           6.5    1444  3.450242
# 38720               Guess Who       230.0           5.5   11638  3.357541
# 1544              Herbstmilch         NaN           NaN   10129  3.321121
# 10532             Aşk Kırmızı         3.0           5.3  210408  3.295626
# 9264         Julia Misbehaves         3.0           6.8   69483  3.282773
# 36365                 The Ref        99.0           6.7   10872  3.275088
# 3209               Lawyer Man         1.0           6.0  126922  3.225177
# 24347    Five Nights in Maine        14.0           5.4  356901  3.091501
# 39953          Monster-in-Law       413.0           5.6    4379  3.043959
# 35934  I Hate Valentine's Day        88.0           5.0   20825  2.975873
# 39484            Over the Top       331.0           5.7    1825  2.455781
# 38667              Date Movie       225.0           3.6   10073  2.183470

# %%
# User 1 (270897) Movie Recc 2: Father of the Bride
u1_recc_titles2, u1_recc_movies2 = hybrid_recommender(270897, 'Father of the Bride')
print("Hybrid Recommender Suggested Movies: \n", u1_recc_titles2)
u1_recc_movies2
# Out:
# Hybrid Recommender Suggested Movies:
#  ['Meet the Parents', 'The Intern', 'My Big Fat Greek Wedding', 'The Holiday', "Something's Gotta Give", 'What Women Want', 'Counting Backwards', 'Lucky 7', 'Make Way for Tomorrow', 'Путь к себе', 'Shopgirl', 'Father of the Bride Part II', 'Baby Boom', "It's Complicated", 'Private Benjamin', '¡A volar joven!', 'The Parent Trap', 'Irreconcilable Differences', 'Little Fockers', 'I Love Trouble']
#                              Title  Vote Count  Vote Average      ID       est
# 41681             Meet the Parents      1743.0           6.6    1597  3.854781
# 41741                   The Intern      1926.0           7.1  257211  3.844290
# 40715     My Big Fat Greek Wedding       686.0           6.2    8346  3.760154
# 41391                  The Holiday      1259.0           6.7    1581  3.699525
# 39986       Something's Gotta Give       422.0           6.3    6964  3.683080
# 41192              What Women Want      1021.0           6.1    3981  3.528582
# 4304            Counting Backwards         1.0           7.0  100634  3.510288
# 26474                      Lucky 7        18.0           4.9   45693  3.506817
# 31768        Make Way for Tomorrow        37.0           7.7   41059  3.487779
# 3800                   Путь к себе         1.0           7.0  420481  3.426556
# 35541                     Shopgirl        80.0           5.7    2610  3.403644
# 38042  Father of the Bride Part II       173.0           5.7   11862  3.394388
# 34996                    Baby Boom        70.0           6.0   11215  3.390860
# 39721             It's Complicated       370.0           6.2   22897  3.350845
# 36488             Private Benjamin       103.0           6.0   10765  3.348766
# 2844               ¡A volar joven!         1.0           6.0   82767  3.250225
# 40865              The Parent Trap       768.0           6.8    9820  3.246162
# 24026   Irreconcilable Differences        14.0           5.0   47874  3.170126
# 41264               Little Fockers      1092.0           5.5   39451  3.115245
# 32348               I Love Trouble        41.0           5.3   10879  3.054277

# %% [markdown]
# From these results, it is evident that the hybrid recommender successfully produces movies that are both similar in genre but also similar to the user's previous ratings and preferences for romantic comedies. The hybrid model also returns the predicted user rating for each suggested movie and ranks from highest to lowest rating, indicating that the user's movie likes and dislikes are playing a role in the movies that are suggested, instead of just solely based off of the metadata.

# %% [markdown]
# **User 2 (270898) - Action Movies Fanatic:**

# %%
# User 2 (270898) Movie Recc 1: Die Hard
u2_recc_titles1, u2_recc_movies1 = hybrid_recommender(270898, 'Die Hard')
print("Hybrid Recommender Suggested Movies: \n", u2_recc_titles1)
u2_recc_movies1
# Out:
# Hybrid Recommender Suggested Movies:
#  ['Live Free or Die Hard', 'Die Hard 2', 'Hitch Hike', 'Die Hard: With a Vengeance', 'A Life Less Ordinary', 'Commando', 'Death Walks on High Heels', 'Killing Zoe', 'Blast', 'Wind River', 'Executive Decision', 'Crash Landing', 'First Kill', 'Hear No Evil', 'End Game', '7 Seconds', 'A Good Day to Die Hard', 'Stratton', 'Extraction', 'Street Fighter']
#                             Title  Vote Count  Vote Average      ID       est
# 41808       Live Free or Die Hard      2122.0           6.4    1571  3.627363
# 41737                  Die Hard 2      1920.0           6.6    1573  3.572741
# 28286                  Hitch Hike        22.0           6.5   54523  3.571463
# 41798  Die Hard: With a Vengeance      2094.0           6.9    1572  3.534645
# 37216        A Life Less Ordinary       130.0           6.2    8067  3.461202
# 40835                    Commando       753.0           6.4   10999  3.401308
# 19932   Death Walks on High Heels         9.0           6.7   77029  3.347479
# 36744                 Killing Zoe       111.0           6.1     507  3.288906
# 23130                       Blast        12.0           4.6   24775  3.222696
# 38150                  Wind River       181.0           7.4  395834  3.208929
# 38988          Executive Decision       261.0           5.8    2320  3.181512
# 17964               Crash Landing         7.0           4.7   86254  3.064214
# 31917                  First Kill        38.0           5.2  410554  3.036861
# 15605                Hear No Evil         6.0           4.7   71140  3.030269
# 28526                    End Game        23.0           5.3    9727  3.005941
# 33577                   7 Seconds        51.0           4.3    9721  2.756255
# 42060      A Good Day to Die Hard      3519.0           5.2   47964  2.677138
# 29386                    Stratton        26.0           4.8  348389  2.666727
# 36473                  Extraction       102.0           4.3  326425  2.635417
# 39477              Street Fighter       330.0           4.1   11667  2.262360

# %%
# User 2 (270898) Movie Recc 2: Lethal Weapon
u2_recc_titles2, u2_recc_movies2 = hybrid_recommender(270898, 'Lethal Weapon')
print("Hybrid Recommender Suggested Movies: \n", u2_recc_titles2)
u2_recc_movies2
# Out:
# Hybrid Recommender Suggested Movies:
#  ['Lethal Weapon 4', 'Lethal Weapon 2', 'Confidence', 'Lethal Weapon 3', 'Under New Management', 'Guardian Angels', 'Sweet Alibis', 'Once a Thief', 'I Accidentally Domed Your Son', 'Love, Honour and Obey', 'Red Eagle', 'Johnny Dangerously', 'Turner & Hooch', 'Kill Me Later', 'Triggermen', 'Point Break', 'Rege', 'Homegrown', 'Money for Nothing', 'Bitch Slap']
#                                Title  Vote Count  Vote Average      ID  \
# 40884                Lethal Weapon 4       782.0           6.3     944
# 41235                Lethal Weapon 2      1066.0           6.7     942
# 37160                     Confidence       127.0           6.4   10743
# 40934                Lethal Weapon 3       824.0           6.4     943
# 5654            Under New Management         2.0           6.0   62399
# 32605                Guardian Angels        43.0           6.0   51191
# 4353                    Sweet Alibis         1.0           6.0  254155
# 30052                   Once a Thief        28.0           6.7   47423
# 4822   I Accidentally Domed Your Son         1.0           7.0   77118
# 28405          Love, Honour and Obey        23.0           6.6   18002
# 19994                      Red Eagle         9.0           5.8   50583
# 34794             Johnny Dangerously        67.0           6.3   16806
# 39513                 Turner & Hooch       335.0           5.9    6951
# 19302                  Kill Me Later         8.0           6.0   35176
# 10676                     Triggermen         3.0           4.7   24079
# 40995                    Point Break       861.0           6.9    1089
# 4263                            Rege         1.0           8.0  313653
# 25357                      Homegrown        16.0           5.5   17133
# 27922              Money for Nothing        21.0           5.1   55448
# 36106                     Bitch Slap        92.0           4.5   26715
#
#             est
# 40884  3.561604
# 41235  3.547417
# 37160  3.459780
# 40934  3.448096
# 5654   3.293800
# 32605  3.242955
# 4353   3.236568
# 30052  3.215961
# 4822   3.181557
# 28405  3.172680
# 19994  3.152228
# 34794  3.125953
# 39513  3.039575
# 19302  3.038557
# 10676  3.027019
# 40995  3.023808
# 4263   2.988442
# 25357  2.971941
# 27922  2.909191
# 36106  2.513935

# %% [markdown]
# From these results, it is evident that the hybrid recommender successfully produces movies that are both similar in the action genre but also similar to the user's previous ratings and preferences for action/thriller movies. The hybrid model also returns the predicted user rating for each suggested movie and ranks from highest to lowest rating, indicating that the user's movie likes and dislikes are playing a role in the movies that are suggested, instead of just solely based off of the metadata.

# %% [markdown]
# **User 3 (270899) - Bollywood Movies Fanatic:**

# %%
# User 3 (270899) Movie Recc 1: Dilwale Dulhania Le Jayenge
u3_recc_titles1, u3_recc_movies1 = hybrid_recommender(270899, 'Dilwale Dulhania Le Jayenge')
print("Hybrid Recommender Suggested Movies: \n", u3_recc_titles1)
u3_recc_movies1
# Out:
# Hybrid Recommender Suggested Movies:
#  ['Rab Ne Bana Di Jodi', 'Om Shanti Om', 'Veer-Zaara', 'Silja - nuorena nukkunut', 'Daawat-e-Ishq', 'A perfect match', 'All The Days Before Tomorrow', 'Aşk Kırmızı', 'Boynton Beach Club', 'Divine Intervention', 'Love Stories', 'Jab Tak Hai Jaan', 'Dil To Pagal Hai', 'The Bridal Party in Hardanger', 'The Trouble with Dee Dee', 'Babycakes', 'The Matriarch', 'Chalte Chalte', 'My Name Is Khan', 'Mujhse Dosti Karoge!']
#                                Title  Vote Count  Vote Average      ID  \
# 34655            Rab Ne Bana Di Jodi        64.0           6.7   14072
# 35766                   Om Shanti Om        85.0           7.2    8079
# 34850                     Veer-Zaara        67.0           7.5    4251
# 158         Silja - nuorena nukkunut         NaN           NaN  468343
# 25200                  Daawat-e-Ishq        15.0           6.8  291154
# 2222                 A perfect match         NaN           NaN   52738
# 1275    All The Days Before Tomorrow         NaN           NaN   19509
# 10532                    Aşk Kırmızı         3.0           5.3  210408
# 10839             Boynton Beach Club         3.0           6.8   55831
# 894              Divine Intervention         NaN           NaN   99885
# 34245                   Love Stories        59.0           6.9   11518
# 34875               Jab Tak Hai Jaan        68.0           7.2  132316
# 32404               Dil To Pagal Hai        41.0           6.6   13986
# 92     The Bridal Party in Hardanger         NaN           NaN  102024
# 715         The Trouble with Dee Dee         NaN           NaN   49218
# 5547                       Babycakes         1.0           4.0  214216
# 8498                   The Matriarch         3.0           5.3  148077
# 29823                  Chalte Chalte        27.0           6.2    4252
# 38783                My Name Is Khan       237.0           7.7   26022
# 25127           Mujhse Dosti Karoge!        15.0           6.1   26277
#
#             est
# 34655  3.847915
# 35766  3.601545
# 34850  3.594865
# 158    3.593886
# 25200  3.503471
# 2222   3.501428
# 1275   3.500995
# 10532  3.497808
# 10839  3.401184
# 894    3.333921
# 34245  3.301724
# 34875  3.300154
# 32404  3.274313
# 92     3.274223
# 715    3.271670
# 5547   3.242347
# 8498   3.194917
# 29823  3.150019
# 38783  3.117364
# 25127  2.960030

# %%
# User 3 (270899) Movie Recc 2: Kabhi Khushi Kabhie Gham
u3_recc_titles2, u3_recc_movies2 = hybrid_recommender(270899, 'Kabhi Khushi Kabhie Gham')
print("Hybrid Recommender Suggested Movies: \n", u3_recc_titles2)
u3_recc_movies2
# Out:
# Hybrid Recommender Suggested Movies:
#  ['Kuch Kuch Hota Hai', 'Dilwale Dulhania Le Jayenge', 'Dark Blue Almost Black', 'Wrong Side Up', 'The Living Room of the Nation', 'Veer-Zaara', 'Elizabeth Ekadashi', 'Prince of Broadway', 'Kal Ho Naa Ho', 'Chupke Chupke', "The Fourth Annual 'On Cinema' Oscar Special", 'The Flying Dutchman', 'Return to Me', 'The Trouble with Dee Dee', 'Ae Dil Hai Mushkil', 'The Matriarch', 'Yedyanchi Jatra', 'Kabhi Alvida Naa Kehna', 'My Name Is Khan', 'Student of the Year']
#                                              Title  Vote Count  Vote Average  \
# 36169                           Kuch Kuch Hota Hai        93.0           7.5
# 40663                  Dilwale Dulhania Le Jayenge       661.0           9.1
# 28607                       Dark Blue Almost Black        23.0           6.7
# 5643                                 Wrong Side Up         2.0           6.0
# 7459                 The Living Room of the Nation         2.0           4.8
# 34850                                   Veer-Zaara        67.0           7.5
# 1937                            Elizabeth Ekadashi         NaN           NaN
# 10026                           Prince of Broadway         3.0           6.7
# 36719                                Kal Ho Naa Ho       110.0           7.3
# 20663                                Chupke Chupke        10.0           7.5
# 79     The Fourth Annual 'On Cinema' Oscar Special         NaN           NaN
# 3473                           The Flying Dutchman         1.0           9.0
# 34860                                 Return to Me        68.0           6.1
# 715                       The Trouble with Dee Dee         NaN           NaN
# 33824                           Ae Dil Hai Mushkil        54.0           6.2
# 8498                                 The Matriarch         3.0           5.3
# 2497                               Yedyanchi Jatra         NaN           NaN
# 32928                       Kabhi Alvida Naa Kehna        45.0           6.1
# 38783                              My Name Is Khan       237.0           7.7
# 33342                          Student of the Year        49.0           6.2
#
#            ID       est
# 36169   11854  3.859270
# 40663   19404  3.840590
# 28607    3865  3.710355
# 5643    26826  3.679387
# 7459   266740  3.625779
# 34850    4251  3.594865
# 1937   305594  3.591911
# 10026   87081  3.552827
# 36719    4254  3.543006
# 20663   21459  3.482539
# 79     443113  3.393704
# 3473    71063  3.331755
# 34860    2621  3.306151
# 715     49218  3.271670
# 33824  393445  3.223906
# 8498   148077  3.194917
# 2497   100783  3.188201
# 32928   14395  3.145785
# 38783   26022  3.117364
# 33342  138122  2.758253

# %% [markdown]
# From these results, it is evident that the hybrid recommender successfully produces movies that are both similar in the international Bollywood genre but also similar to the user's previous ratings and preferences for Bollywood movies. The hybrid model also returns the predicted user rating for each suggested movie and ranks from highest to lowest rating, indicating that the user's movie likes and dislikes are playing a role in the movies that are suggested, instead of just solely based off of the metadata.

# %% [markdown]
# ## Models Comparison

# %% [markdown]
# In order to display the benefits of a hybrid recommender system, the following code will test each model with the same 7 movies and 2 user profiles to display the varying results of both the individual content-based and collabroative filtering models and the combination in the hybrid model.

# %% [markdown]
# To compare the results of each recommender, the 3 models will be tested with the following 7 movies:
# - Legally Blonde - 106910
# - Kabhi Khushi Kabhie Gham - 27362
# - The Avengers - 89745
# - The Dark Knight - 58559
# - Harry Potter and the Philosopher's Stone - 4896
# - Tangled - 81847
# - Cinderella - 130073
#
# The user profiles will be Users 32, 7954, and 270898 that were randomly selected from the user ratings dataset, as they each have varying movie tastes that are included in this selection of 7 movies to test with.

# %%
movie_names = ["Legally Blonde", "Kabhi Khushi Kabhie Gham", "The Avengers", "The Dark Knight",
         "Harry Potter and the Philosopher's Stone", "Tangled", "Cinderella"]

movie_ids = [106910, 27362, 89745, 58559, 4896, 81847, 130073]
user_ids = [32, 7954, 270898]

# %% [markdown]
# ### Testing Content Based Recommender System

# %%
for movie in movie_names:
    print("Movie:", movie)
    print("Recommendations:\n", get_recommendations(movie), "\n")
# Out:
# Movie: Legally Blonde
# Recommendations:
#  ['Legally Blonde 2: Red, White & Blonde', 'The Wendell Baker Story', 'Four Christmases', 'Wild', 'Penelope', 'Cruel Intentions', 'Mentor', 'The Last Templar', 'Legally Blondes', 'Tenure', 'Girl', 'Godspell: A Musical Based on the Gospel According to St. Matthew', 'Finding Bliss', 'Life With Mikey', 'Overnight Delivery', 'Dear Eleanor', 'Ordinary World', 'Meadowland', 'Pretty Persuasion']
#
# Movie: Kabhi Khushi Kabhie Gham
# Recommendations:
#  ['Kal Ho Naa Ho', 'Student of the Year', 'The Matriarch', 'Kuch Kuch Hota Hai', 'Kabhi Alvida Naa Kehna', 'My Name Is Khan', 'Ae Dil Hai Mushkil', 'The Trouble with Dee Dee', 'Elizabeth Ekadashi', 'Yedyanchi Jatra', 'Chupke Chupke', 'Dilwale Dulhania Le Jayenge', 'Wrong Side Up', 'The Flying Dutchman', 'The Living Room of the Nation', 'Prince of Broadway', 'Return to Me', 'Dark Blue Almost Black', 'Veer-Zaara']
#
# Movie: The Avengers
# Recommendations:
#  ['Avengers: Age of Ultron', 'Captain America: The Winter Soldier', 'Ant-Man', 'Doctor Strange', 'Thor: The Dark World', 'Captain America: Civil War', 'Iron Man 2', 'Iron Man', 'The Incredible Hulk', 'Thor', 'Marvel One-Shot: Item 47', 'Iron Man 3', 'Marvel Studios: Assembling a Universe', 'Captain America: The First Avenger', 'Avengers Confidential: Black Widow & Punisher', 'Iron Man & Captain America: Heroes United', 'Deadpool', 'Iron Man & Hulk: Heroes United', 'Team Thor']
#
# Movie: The Dark Knight
# Recommendations:
#  ['The Dark Knight Rises', 'Batman Begins', 'Batman: Under the Red Hood', 'The Prestige', 'Batman: Assault on Arkham', 'Following', 'Batman Returns', 'The Holcroft Covenant', 'Inception', 'Dunkirk', 'Shooters', 'Batman: The Killing Joke', 'Batman & Mr. Freeze: SubZero', 'The Last Desperate Hours', 'Doodlebug', 'Evil Behind You', 'Atom Man vs Superman', 'Batman v Superman: Dawn of Justice', 'Chicago Overcoat']
#
# Movie: Harry Potter and the Philosopher's Stone
# Recommendations:
#  ['Harry Potter and the Chamber of Secrets', 'Harry Potter and the Half-Blood Prince', 'Harry Potter and the Goblet of Fire', 'Harry Potter and the Prisoner of Azkaban', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Deathly Hallows: Part 1', 'Harry Potter and the Deathly Hallows: Part 2', 'Bhoot Unkle', "Jill And Joy's Winter", 'A Journey Through Fairyland', 'Wow! A Talking Fish!', 'Percy Jackson & the Olympians: The Lightning Thief', 'Puff, the Magic Dragon', 'All She Wishes', 'The Wonderful Ice Cream Suit', 'Der Struwwelpeter', 'Hocus Pocus', 'Halloweentown High', 'Halloweentown']
#
# Movie: Tangled
# Recommendations:
#  ['Tangled Ever After', 'The Princess and the Frog', 'Cheburashka', 'VeggieTales: Josh and the Big Wall', "VeggieTales: Minnesota Cuke and the Search for Samson's Hairbrush", 'Sleeping Beauty', 'Enchanted', 'Bolt', 'Green Legend Ran', "Jill And Joy's Winter", 'Dragon Hill', 'Malice@Doll', 'Кентервильское привидение', 'Tin Toy', "Red's Dream", 'Luxo Jr.', 'A Flying Ship', 'The Princess and the Goblin', 'Creature Comforts']
#
# Movie: Cinderella
# Recommendations:
#  ['Ever After: A Cinderella Story', 'Three Wishes for Cinderella', 'Sleeping Beauty', 'The Cave of the Golden Rose', 'Aşk Kırmızı', 'Cinderella III: A Twist in Time', 'Cirque du Soleil: Varekai', 'More Than a Miracle', 'Prince and the Evening Star', 'Cinderella II: Dreams Come True', 'Jails, Hospitals & Hip-Hop', 'Sundome', 'Bhoot Unkle', "Jill And Joy's Winter", 'Joni', 'Ill Gotten Gains', 'Το γάλα', 'Counting Backwards', 'A Journey Through Fairyland']

# %% [markdown]
# ### Testing Collaborative Filtering Recommender System

# %% [markdown]
# Surprise package predict method takes in:
# - uid = user ID
# - iid = item id
# - rui = true rating -- optional

# %%
for user_id in user_ids:
    print("User ID:", user_id, "\n")
    for movie, movie_id in zip(movie_names, movie_ids):
        print("Movie:", movie)
        print("Predicted User Rating:", loaded_algo_demo.predict(movie_id, user_id).est, "\n")
    print("\n")
# Out:
# User ID: 32
#
# Movie: Legally Blonde
# Predicted User Rating: 3.6934934876614434
#
# Movie: Kabhi Khushi Kabhie Gham
# Predicted User Rating: 4.1802906024813575
#
# Movie: The Avengers
# Predicted User Rating: 4.948186468730362
#
# Movie: The Dark Knight
# Predicted User Rating: 3.823194515488192
#
# Movie: Harry Potter and the Philosopher's Stone
# Predicted User Rating: 3.8382930494494225
#
# Movie: Tangled
# Predicted User Rating: 3.683635496351337
#
# Movie: Cinderella
# Predicted User Rating: 3.3483236642270393
#
#
#
# User ID: 7954
#
# Movie: Legally Blonde
# Predicted User Rating: 2.92933795379747
#
# Movie: Kabhi Khushi Kabhie Gham
# Predicted User Rating: 2.9390543172382326
#
# Movie: The Avengers
# Predicted User Rating: 3.3426800816452267
#
# Movie: The Dark Knight
# Predicted User Rating: 2.8143656348049277
#
# Movie: Harry Potter and the Philosopher's Stone
# Predicted User Rating: 3.0734163658775433
#
# Movie: Tangled
# Predicted User Rating: 3.0705188458955885
#
# Movie: Cinderella
# Predicted User Rating: 2.4473142252813513
#
#
#
# User ID: 270898
#
# Movie: Legally Blonde
# Predicted User Rating: 3.4225057718961085
#
# Movie: Kabhi Khushi Kabhie Gham
# Predicted User Rating: 3.3965028125473973
#
# Movie: The Avengers
# Predicted User Rating: 3.4950768968331523
#
# Movie: The Dark Knight
# Predicted User Rating: 3.437186775324021
#
# Movie: Harry Potter and the Philosopher's Stone
# Predicted User Rating: 3.6314862273702673
#
# Movie: Tangled
# Predicted User Rating: 3.4319196301267283
#
# Movie: Cinderella
# Predicted User Rating: 3.0260336870679345

# %% [markdown]
# ### Testing Hybrid Recommender System

# %%
for user_id in user_ids:
    print("User ID:", user_id, "\n")
    for movie in movie_names:
        print("Movie:", movie)
        titles, movies = hybrid_recommender(user_id, movie)
        print("Suggested Movies and Predicted User Ratings: \n")
        for movie, rating in zip(list(movies["Title"]), list(movies["est"])):
            print(movie, rating)
        print("\n")
# Out:
# User ID: 32
#
# Movie: Legally Blonde
# Suggested Movies and Predicted User Ratings:
#
# Godspell: A Musical Based on the Gospel According to St. Matthew 3.9334896722137738
# Pretty Persuasion 3.781224660451396
# Cruel Intentions 3.746325943668475
# Wild 3.7350694409513294
# Girl 3.723586531289791
# Overnight Delivery 3.721213307054958
# Tenure 3.6657161656638615
# Meadowland 3.6464649707900874
# The Man in the Moon 3.583872461106615
# Mentor 3.5818062281133547
# Dear Eleanor 3.556816034437301
# The Last Templar 3.540615656821905
# Penelope 3.402715989758105
# Ordinary World 3.3224954607287582
# The Wendell Baker Story 3.3022977886417704
# Life With Mikey 3.293558262474821
# Four Christmases 3.2689747023010414
# Finding Bliss 3.2679770091376534
# Legally Blonde 2: Red, White & Blonde 3.0550069382143725
# Legally Blondes 2.8295076745077523
#
#
# Movie: Kabhi Khushi Kabhie Gham
# Suggested Movies and Predicted User Ratings:
#
# Dilwale Dulhania Le Jayenge 4.278663970650635
# Kuch Kuch Hota Hai 4.148588462335488
# Chupke Chupke 4.113368703027184
# Kal Ho Naa Ho 4.033833895438041
# Wrong Side Up 3.9952206148458167
# The Flying Dutchman 3.976648153973625
# The Living Room of the Nation 3.9158153223334766
# Elizabeth Ekadashi 3.8576238852603693
# Dark Blue Almost Black 3.853379814857302
# My Name Is Khan 3.7941071819607433
# Prince of Broadway 3.7695341379449054
# Kabhi Alvida Naa Kehna 3.732427553778124
# The Fourth Annual 'On Cinema' Oscar Special 3.6744667499271024
# Ae Dil Hai Mushkil 3.63202352242489
# Return to Me 3.526686706945774
# The Trouble with Dee Dee 3.4665426398156125
# The Matriarch 3.4365434413654046
# Veer-Zaara 3.4324416842269514
# Yedyanchi Jatra 3.357716538921102
# Student of the Year 3.0486530232771103
#
#
# Movie: The Avengers
# Suggested Movies and Predicted User Ratings:
#
# Doctor Strange 4.354701479360984
# Avengers: Age of Ultron 4.294711214796117
# Thor: The Dark World 4.259378138706772
# Serenity 4.249827540678138
# Iron Man 2 4.194483340847306
# Iron Man 4.1855355955036115
# Thor 4.155355436987333
# Captain America: The First Avenger 4.135445267878148
# Iron Man 3 4.130676975610935
# Captain America: Civil War 4.081837671314666
# Captain America: The Winter Soldier 4.0351598791474785
# Deadpool 4.0322600735635605
# Ant-Man 3.9994050588421426
# Marvel Studios: Assembling a Universe 3.98514877169928
# Team Thor 3.9843444717525367
# The Incredible Hulk 3.9507017647127975
# Marvel One-Shot: Item 47 3.4151995874088636
# Avengers Confidential: Black Widow & Punisher 3.236825980728332
# Iron Man & Hulk: Heroes United 3.209093364997594
# Iron Man & Captain America: Heroes United 2.982528389644481
#
#
# Movie: The Dark Knight
# Suggested Movies and Predicted User Ratings:
#
# The Dark Knight Rises 4.534986346756044
# Inception 4.4196097292534295
# Batman v Superman: Dawn of Justice 4.25802217658684
# Batman Begins 4.252114822569089
# The Prestige 4.22723611032672
# Dunkirk 4.149635820990097
# Batman: Under the Red Hood 4.025056880752624
# Batman: Assault on Arkham 4.010779477006836
# Chicago Overcoat 3.9962959930848627
# Batman: The Killing Joke 3.8237507636734676
# Following 3.7974544260150553
# Batman Returns 3.641219041666656
# Atom Man vs Superman 3.561788040005085
# The Last Desperate Hours 3.531254305406043
# Shooters 3.502405425783385
# Doodlebug 3.4754174303438514
# Batman & Mr. Freeze: SubZero 3.383104666634222
# Evil Behind You 3.3757596505758953
# The Holcroft Covenant 3.2749182462430264
# Renegades 2.9510174039976795
#
#
# Movie: Harry Potter and the Philosopher's Stone
# Suggested Movies and Predicted User Ratings:
#
# Puff, the Magic Dragon 3.930068807038528
# Harry Potter and the Deathly Hallows: Part 2 3.8076882815922217
# Harry Potter and the Half-Blood Prince 3.7914066275900367
# Halloweentown High 3.776068069156501
# Harry Potter and the Deathly Hallows: Part 1 3.7594277091706534
# Harry Potter and the Order of the Phoenix 3.7372343608643153
# Harry Potter and the Goblet of Fire 3.7250685799755416
# Harry Potter and the Prisoner of Azkaban 3.721618194118341
# Wow! A Talking Fish! 3.7059763740794467
# A Journey Through Fairyland 3.6862082845733144
# Harry Potter and the Chamber of Secrets 3.6467605733747726
# Percy Jackson & the Olympians: The Lightning Thief 3.6455925889333556
# The Wonderful Ice Cream Suit 3.6393229851704945
# Der Struwwelpeter 3.6263532510388647
# All She Wishes 3.5827733169481366
# Bhoot Unkle 3.5710253470057833
# Jill And Joy's Winter 3.4066017636395687
# The Seeker: The Dark Is Rising 3.3767749580990367
# Halloweentown 3.3730167227460517
# Hocus Pocus 3.249307130011152
#
#
# Movie: Tangled
# Suggested Movies and Predicted User Ratings:
#
# Green Legend Ran 3.9852553095057965
# Creature Comforts 3.8517953839091827
# Dragon Hill 3.8178402560854816
# Tangled Ever After 3.803004945122349
# The Princess and the Goblin 3.7871442545631155
# Cheburashka 3.765992961320193
# Enchanted 3.7588769682107452
# The Princess and the Frog 3.718888972949282
# Superstar Goofy 3.7182088791839174
# Luxo Jr. 3.675503683018384
# Bolt 3.617044577045774
# Кентервильское привидение 3.574713295521132
# A Flying Ship 3.55784649635513
# Tin Toy 3.5358689130315666
# Red's Dream 3.4971074810818688
# VeggieTales: Minnesota Cuke and the Search for Samson's Hairbrush 3.466507571085679
# Sleeping Beauty 3.463231598454759
# VeggieTales: Josh and the Big Wall 3.4066941602037057
# Jill And Joy's Winter 3.4066017636395687
# Malice@Doll 3.379987898219765
#
#
# Movie: Cinderella
# Suggested Movies and Predicted User Ratings:
#
# Ever After: A Cinderella Story 4.051093147983014
# Three Wishes for Cinderella 4.018738947523039
# Το γάλα 3.9341161511712817
# Cirque du Soleil: Varekai 3.7450233589177637
# Aşk Kırmızı 3.716770222794495
# A Journey Through Fairyland 3.6862082845733144
# Counting Backwards 3.6786670097258094
# More Than a Miracle 3.6696024702872783
# The Cave of the Golden Rose 3.606350258367869
# National Geographic American Blackout 3.5839147702441387
# Bhoot Unkle 3.5710253470057833
# Prince and the Evening Star 3.5341698530270396
# Joni 3.50361356071507
# Sleeping Beauty 3.463231598454759
# Jill And Joy's Winter 3.4066017636395687
# Cinderella III: A Twist in Time 3.3580341672211187
# Jails, Hospitals & Hip-Hop 3.3490616983562496
# Sundome 3.339205034456855
# Cinderella II: Dreams Come True 3.0221665354572673
# Ill Gotten Gains 2.950829270795915
#
#
# User ID: 7954
#
# Movie: Legally Blonde
# Suggested Movies and Predicted User Ratings:
#
# Godspell: A Musical Based on the Gospel According to St. Matthew 3.7987153691803828
# The Man in the Moon 3.784794715429917
# Penelope 3.6482994391210353
# Cruel Intentions 3.6431231800444386
# Wild 3.5750020826672477
# Pretty Persuasion 3.5624697526029525
# Girl 3.5094088219595756
# Finding Bliss 3.4621480601889454
# Dear Eleanor 3.442938615938634
# Mentor 3.382824657403042
# Tenure 3.3775108041514135
# Meadowland 3.3742561084573954
# The Last Templar 3.2245126923395273
# Ordinary World 3.215600327553481
# The Wendell Baker Story 3.2065651553580623
# Life With Mikey 3.105164628086494
# Four Christmases 2.9759347431599372
# Overnight Delivery 2.9314035190842023
# Legally Blondes 2.8224086044011005
# Legally Blonde 2: Red, White & Blonde 2.5173418487269106
#
#
# Movie: Kabhi Khushi Kabhie Gham
# Suggested Movies and Predicted User Ratings:
#
# Dilwale Dulhania Le Jayenge 3.8889566371927358
# The Living Room of the Nation 3.847634132585298
# Return to Me 3.839077809099955
# Veer-Zaara 3.7865978559657494
# Elizabeth Ekadashi 3.770504490070636
# Kuch Kuch Hota Hai 3.7688469837274154
# Dark Blue Almost Black 3.7109445385019946
# Wrong Side Up 3.694287973442526
# The Fourth Annual 'On Cinema' Oscar Special 3.6811051225251163
# My Name Is Khan 3.67549971215577
# Chupke Chupke 3.6120278850694705
# The Trouble with Dee Dee 3.5368408079959446
# Prince of Broadway 3.511397954059781
# The Flying Dutchman 3.4786093539356453
# Kal Ho Naa Ho 3.4785111269638924
# Yedyanchi Jatra 3.271799167422804
# Ae Dil Hai Mushkil 3.2704766787100605
# The Matriarch 3.1719030827841292
# Kabhi Alvida Naa Kehna 3.16413724275901
# Student of the Year 2.9283480082249964
#
#
# Movie: The Avengers
# Suggested Movies and Predicted User Ratings:
#
# Iron Man 4.0018423090594775
# Serenity 3.9698171486666207
# Captain America: Civil War 3.8625885274333216
# Team Thor 3.7569039429875404
# Marvel Studios: Assembling a Universe 3.7237946438135725
# Captain America: The Winter Soldier 3.7117783510670233
# Avengers: Age of Ultron 3.69811713943352
# Doctor Strange 3.670675310896963
# Ant-Man 3.650776057970439
# Deadpool 3.629316555189463
# Captain America: The First Avenger 3.581900498723619
# Thor 3.492805855660458
# Iron Man 2 3.4883636173337575
# Iron Man 3 3.457563708174352
# Thor: The Dark World 3.3967187792872195
# Marvel One-Shot: Item 47 3.3511731836707224
# The Incredible Hulk 3.3440111320350665
# Iron Man & Captain America: Heroes United 3.118929053042686
# Iron Man & Hulk: Heroes United 3.1180067437994983
# Avengers Confidential: Black Widow & Punisher 3.0770219754102524
#
#
# Movie: The Dark Knight
# Suggested Movies and Predicted User Ratings:
#
# Inception 4.295890188639123
# The Prestige 4.166760491786089
# The Dark Knight Rises 4.063919264427504
# Dunkirk 4.013450663877568
# Batman Begins 3.94781069590833
# The Last Desperate Hours 3.8208091970668643
# Chicago Overcoat 3.762519346728172
# Following 3.704185275574641
# Batman: Assault on Arkham 3.6547230419171943
# Batman: Under the Red Hood 3.5444584344342225
# Batman & Mr. Freeze: SubZero 3.4486142690054016
# Evil Behind You 3.37175635812592
# Shooters 3.3101909602601727
# Doodlebug 3.2938159809396255
# The Holcroft Covenant 3.1687812151115238
# Atom Man vs Superman 3.14667338156611
# Batman: The Killing Joke 3.102887124806717
# Batman Returns 2.869041202912759
# Batman v Superman: Dawn of Justice 2.851541897914245
# Renegades 2.7292751321376203
#
#
# Movie: Harry Potter and the Philosopher's Stone
# Suggested Movies and Predicted User Ratings:
#
# Harry Potter and the Deathly Hallows: Part 2 4.118785959675269
# Harry Potter and the Half-Blood Prince 3.9899487413226855
# Harry Potter and the Deathly Hallows: Part 1 3.97424916099417
# Harry Potter and the Prisoner of Azkaban 3.9505420331319403
# Harry Potter and the Goblet of Fire 3.9439159077976287
# Harry Potter and the Order of the Phoenix 3.9328345328524943
# Harry Potter and the Chamber of Secrets 3.866148391880199
# Puff, the Magic Dragon 3.791565614114857
# All She Wishes 3.6544818833740083
# Wow! A Talking Fish! 3.6023758460058515
# Jill And Joy's Winter 3.5753113011982234
# The Wonderful Ice Cream Suit 3.5471888923010915
# A Journey Through Fairyland 3.539523663505201
# Bhoot Unkle 3.2758808957386836
# Der Struwwelpeter 3.271000871641453
# Halloweentown 3.2644765493363628
# Halloweentown High 3.1746996022891327
# Percy Jackson & the Olympians: The Lightning Thief 3.027840724677705
# Hocus Pocus 2.85136225361657
# The Seeker: The Dark Is Rising 2.798825961710173
#
#
# Movie: Tangled
# Suggested Movies and Predicted User Ratings:
#
# Tangled Ever After 3.9715679605101455
# Luxo Jr. 3.8919273864675814
# Green Legend Ran 3.7930390377312144
# Enchanted 3.764754578290384
# Creature Comforts 3.741132894768464
# Кентервильское привидение 3.6836119543681916
# Sleeping Beauty 3.5903781259746617
# Jill And Joy's Winter 3.5753113011982234
# Malice@Doll 3.4986618866114303
# Bolt 3.48053304290343
# Cheburashka 3.458082459660996
# The Princess and the Frog 3.445481646609755
# Tin Toy 3.4380370968962093
# Red's Dream 3.402545799270534
# Superstar Goofy 3.3328261478899512
# VeggieTales: Minnesota Cuke and the Search for Samson's Hairbrush 3.32787685053694
# A Flying Ship 3.303304174306695
# The Princess and the Goblin 3.286495868094234
# Dragon Hill 3.208067067366248
# VeggieTales: Josh and the Big Wall 3.192405251356674
#
#
# Movie: Cinderella
# Suggested Movies and Predicted User Ratings:
#
# Three Wishes for Cinderella 3.9937832433595566
# Το γάλα 3.9219585174450753
# Counting Backwards 3.7737440745319377
# Prince and the Evening Star 3.7181623116803078
# Cirque du Soleil: Varekai 3.7160264693805964
# Ever After: A Cinderella Story 3.643994560486242
# National Geographic American Blackout 3.640569039090282
# Sleeping Beauty 3.5903781259746617
# Jill And Joy's Winter 3.5753113011982234
# Joni 3.5736446990015382
# More Than a Miracle 3.568924865351908
# A Journey Through Fairyland 3.539523663505201
# Aşk Kırmızı 3.503275337771978
# The Cave of the Golden Rose 3.412699266603725
# Bhoot Unkle 3.2758808957386836
# Sundome 3.2622672991748796
# Jails, Hospitals & Hip-Hop 3.18585868166966
# Cinderella III: A Twist in Time 3.0158728512904007
# Ill Gotten Gains 2.823800725544186
# Cinderella II: Dreams Come True 2.612152335007203
#
#
# User ID: 270898
#
# Movie: Legally Blonde
# Suggested Movies and Predicted User Ratings:
#
# Godspell: A Musical Based on the Gospel According to St. Matthew 3.7394846946900206
# Girl 3.368619010991658
# Mentor 3.3101397497435867
# Dear Eleanor 3.2498898097263718
# Meadowland 3.2432259431557635
# Wild 3.228771177656507
# Cruel Intentions 3.2049486978587742
# Finding Bliss 3.029758736605317
# Tenure 2.9895710150910975
# Penelope 2.9851287755241223
# Pretty Persuasion 2.958294292214281
# The Man in the Moon 2.9534076218611562
# Ordinary World 2.9212426430710203
# Overnight Delivery 2.9117294311400865
# The Last Templar 2.8833420987033045
# The Wendell Baker Story 2.8443207194979907
# Legally Blondes 2.8270466972089388
# Four Christmases 2.7616231239800397
# Life With Mikey 2.6206861539610165
# Legally Blonde 2: Red, White & Blonde 1.8531686754932082
#
#
# Movie: Kabhi Khushi Kabhie Gham
# Suggested Movies and Predicted User Ratings:
#
# The Living Room of the Nation 3.5661695152158432
# The Flying Dutchman 3.5628507014515187
# Dilwale Dulhania Le Jayenge 3.510539222566401
# Dark Blue Almost Black 3.4919189743753454
# Kal Ho Naa Ho 3.4910932922207043
# Wrong Side Up 3.4800803075365723
# Veer-Zaara 3.4148760981910433
# Chupke Chupke 3.396840005234091
# Elizabeth Ekadashi 3.336848491677592
# The Fourth Annual 'On Cinema' Oscar Special 3.322597445458631
# Kuch Kuch Hota Hai 3.272374545997504
# Prince of Broadway 3.223497708240588
# The Trouble with Dee Dee 3.080244714806846
# My Name Is Khan 3.0292914349834823
# Yedyanchi Jatra 3.0206642770785255
# Return to Me 2.9560247302510536
# Kabhi Alvida Naa Kehna 2.9447375953404955
# The Matriarch 2.91745841654109
# Ae Dil Hai Mushkil 2.802508889178205
# Student of the Year 2.618415439035728
#
#
# Movie: The Avengers
# Suggested Movies and Predicted User Ratings:
#
# Iron Man 3.9785045560573846
# Serenity 3.86566164175967
# Iron Man 2 3.696817477025444
# Marvel Studios: Assembling a Universe 3.67206700809397
# Captain America: Civil War 3.652699204587694
# Iron Man 3 3.6261945142574405
# Avengers: Age of Ultron 3.5714516952583226
# Team Thor 3.545354993900073
# The Incredible Hulk 3.484228183009379
# Thor 3.4817855398774236
# Thor: The Dark World 3.4584073437208653
# Captain America: The First Avenger 3.453734623879758
# Captain America: The Winter Soldier 3.4536570544343643
# Doctor Strange 3.4457767301007625
# Ant-Man 3.274473265517621
# Deadpool 3.1258632160712705
# Marvel One-Shot: Item 47 3.066070256828981
# Avengers Confidential: Black Widow & Punisher 2.8369568910265195
# Iron Man & Captain America: Heroes United 2.7718412619037824
# Iron Man & Hulk: Heroes United 2.750549949923127
#
#
# Movie: The Dark Knight
# Suggested Movies and Predicted User Ratings:
#
# Inception 3.9946324745614423
# Batman Begins 3.850074447037331
# The Prestige 3.8429238065853473
# The Dark Knight Rises 3.825119740423887
# Dunkirk 3.789431566765454
# Following 3.538952058108145
# Batman: Under the Red Hood 3.38484449016217
# Chicago Overcoat 3.3539127852873487
# Batman: Assault on Arkham 3.285030654287111
# Shooters 3.281094993869427
# The Last Desperate Hours 3.1948447630581915
# Doodlebug 3.125815922671738
# Batman Returns 3.042216410590862
# Evil Behind You 2.982177930683407
# Batman & Mr. Freeze: SubZero 2.980796473839976
# Batman: The Killing Joke 2.9372577385070637
# Atom Man vs Superman 2.9299397957942066
# Batman v Superman: Dawn of Justice 2.9158732163625185
# The Holcroft Covenant 2.807641507554176
# Renegades 2.5321672726731435
#
#
# Movie: Harry Potter and the Philosopher's Stone
# Suggested Movies and Predicted User Ratings:
#
# Puff, the Magic Dragon 3.589668669769523
# Harry Potter and the Half-Blood Prince 3.577217180368132
# Harry Potter and the Goblet of Fire 3.552529829371744
# Harry Potter and the Prisoner of Azkaban 3.5403444564397386
# Harry Potter and the Deathly Hallows: Part 2 3.5390398070633453
# Harry Potter and the Deathly Hallows: Part 1 3.509244643013584
# Harry Potter and the Order of the Phoenix 3.4986974059008062
# Der Struwwelpeter 3.4657748680069735
# Harry Potter and the Chamber of Secrets 3.396418826630887
# Wow! A Talking Fish! 3.325187774562111
# Bhoot Unkle 3.2112831548777123
# Jill And Joy's Winter 3.1842480668526374
# All She Wishes 3.1728312790733186
# The Wonderful Ice Cream Suit 3.160134377508184
# A Journey Through Fairyland 3.1096653177159164
# Halloweentown High 2.891567314815033
# Halloweentown 2.807033101827053
# The Seeker: The Dark Is Rising 2.7299962704258482
# Percy Jackson & the Olympians: The Lightning Thief 2.637109453617056
# Hocus Pocus 2.245761688966041
#
#
# Movie: Tangled
# Suggested Movies and Predicted User Ratings:
#
# Green Legend Ran 3.4478967299110153
# Creature Comforts 3.443758571152039
# Cheburashka 3.3368234042377027
# Bolt 3.329427466871769
# Luxo Jr. 3.297778925689495
# A Flying Ship 3.2810831756709313
# Кентервильское привидение 3.259065718384932
# Tin Toy 3.237650256991978
# VeggieTales: Josh and the Big Wall 3.2068568724124504
# Jill And Joy's Winter 3.1842480668526374
# Tangled Ever After 3.172277142640969
# Malice@Doll 3.1516616617854707
# Dragon Hill 3.1411863957428254
# VeggieTales: Minnesota Cuke and the Search for Samson's Hairbrush 3.096164216327348
# Red's Dream 3.0902198006658628
# Superstar Goofy 3.078357537960426
# Enchanted 3.059333206781092
# The Princess and the Goblin 3.056328571192338
# The Princess and the Frog 2.956298216551815
# Sleeping Beauty 2.783879270602628
#
#
# Movie: Cinderella
# Suggested Movies and Predicted User Ratings:
#
# Three Wishes for Cinderella 3.6372242183645516
# Cirque du Soleil: Varekai 3.4607923175151405
# Το γάλα 3.44565474022279
# National Geographic American Blackout 3.4060880093228643
# Joni 3.281444541639285
# Ever After: A Cinderella Story 3.2654748942896035
# Bhoot Unkle 3.2112831548777123
# Counting Backwards 3.20144440357463
# Jill And Joy's Winter 3.1842480668526374
# Prince and the Evening Star 3.182296423610998
# Sundome 3.1539777317791065
# Jails, Hospitals & Hip-Hop 3.1253209865886324
# A Journey Through Fairyland 3.1096653177159164
# More Than a Miracle 3.089055626944799
# The Cave of the Golden Rose 3.0155046763018647
# Aşk Kırmızı 2.9980076422195805
# Cinderella III: A Twist in Time 2.7979827287649583
# Sleeping Beauty 2.783879270602628
# Ill Gotten Gains 2.59336482919233
# Cinderella II: Dreams Come True 2.512360145026516

# %% [markdown]
# From the results of the 3 models, it is evident that the hybrid recommender system performs the best at recommending movies tailored to each user while also incorporating features about the movie's metadata. While the content-based recommender solely recommends movies based on the movie features and the content-based recommender reports predicted ratings based on the user's past movie preferences, the hybrid model combines the strengths of both models and suggests movies that not only have similar metadata features but also that the user is predicted to give a higher rating to.
