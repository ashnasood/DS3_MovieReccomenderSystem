# %% [markdown]
# # **Movies Dataset Content-Based, Collaborative Filtering, and Hybrid Recommender Models**

# %% [markdown]
# ## **Collaborators**
# - Ashna Sood
# - Urmi Suresh
# - Tae Kim
# - Xianglong Wang

# %% [markdown]
# ## **Imports**

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
import os 
import pickle
import math

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats

from sklearn.metrics import make_scorer, accuracy_score, plot_confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, GridSearchCV
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.manifold import TSNE

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

from nltk.stem.snowball import SnowballStemmer

from sklearn import metrics

# %% [markdown]
# ## **Content Based Recommender System Using Cleaned Metadata**

# %%
# read in cleaned movies metadata csv file
movies_df = pd.read_csv("movies_metadata_cleaned.csv")
movies_df
# Out:
#                ID    IMDB ID              Title               Collection  \
# 0          461257  tt6980792           Queerama                      NaN
# 1           92323  tt0081758    Willie and Phil                      NaN
# 2          114838  tt0029949        Brother Rat                      NaN
# 3          264723  tt0070580         Le pélican                      NaN
# 4           88061  tt0055459  So Evil, So Young                      NaN
# ...           ...        ...                ...                      ...
# 42273       24428  tt0848228       The Avengers    theavengerscollection
# 42274       19995  tt0499549             Avatar         avatarcollection
# 42275         155  tt0468569    The Dark Knight  thedarkknightcollection
# 42276       27205  tt1375666          Inception                      NaN
# 42277  2014-01-01          0                NaN                      NaN
#
#                                                   Genres Language  \
# 0                                                     []       en
# 1                                                     []       en
# 2                                             ['Comedy']       en
# 3                                                     []       en
# 4                                              ['Drama']       en
# ...                                                  ...      ...
# 42273         ['Science Fiction', 'Action', 'Adventure']       en
# 42274  ['Action', 'Adventure', 'Fantasy', 'Science Fi...       en
# 42275           ['Drama', 'Action', 'Crime', 'Thriller']       en
# 42276  ['Action', 'Thriller', 'Science Fiction', 'Mys...       en
# 42277  ['Odyssey Media', 'Pulser Productions', 'Rogue...     82.0
#
#       Spoken Languages Release Date  Runtime       Revenue  ...  \
# 0               ['en']   2017-06-09     75.0           NaN  ...
# 1                   []   1980-08-15    115.0           NaN  ...
# 2               ['en']   1938-10-29     87.0           NaN  ...
# 3                   []   1974-02-06     83.0           NaN  ...
# 4               ['en']   1963-01-01     77.0           NaN  ...
# ...                ...          ...      ...           ...  ...
# 42273           ['en']   2012-04-25    143.0  1.519558e+09  ...
# 42274     ['en', 'es']   2009-12-10    162.0  2.787965e+09  ...
# 42275     ['en', 'zh']   2008-07-16    152.0  1.004558e+09  ...
# 42276           ['en']   2010-07-14    148.0  8.255328e+08  ...
# 42277               []          NaN      NaN           NaN  ...
#
#                                  Production Countries Popularity Rating  \
# 0                                  ['United Kingdom']          0.163015
# 1                                                  []          0.326500
# 2                        ['United States of America']          0.174691
# 3                                                  []          0.000115
# 4                                                  []          0.001662
# ...                                               ...               ...
# 42273                    ['United States of America']         89.887648
# 42274  ['United States of America', 'United Kingdom']        185.070892
# 42275  ['United Kingdom', 'United States of America']        123.167259
# 42276  ['United Kingdom', 'United States of America']         29.108149
# 42277                                             NaN               NaN
#
#        Vote Count  Vote Average  \
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ...           ...           ...
# 42273     12000.0           7.4
# 42274     12114.0           7.2
# 42275     12269.0           8.3
# 42276     14075.0           8.1
# 42277         NaN           NaN
#
#                                                 Keywords  \
# 0                                                     []
# 1                                                     []
# 2                               ['basedonplayormusical']
# 3                                                     []
# 4                            ['prison', "women'sprison"]
# ...                                                  ...
# 42273  ['newyork', 'shield', 'marvelcomic', 'superher...
# 42274  ['cultureclash', 'future', 'spacewar', 'spacec...
# 42275  ['dccomics', 'crimefighter', 'secretidentity',...
# 42276  ['lossoflover', 'dream', 'kidnapping', 'sleep'...
# 42277                                                 []
#
#                                                     Cast          Director  \
# 0                                                     []      daisyasquith
# 1       ['michaelontkean', 'raysharkey', 'margotkidder']      paulmazursky
# 2      ['ronaldreagan', 'janewyman', 'priscillalane',...   williamkeighley
# 3                                                     []       gérardblain
# 4      ['jillireland', 'ellenpollock', 'joanhaythorne...    godfreygrayson
# ...                                                  ...               ...
# 42273  ['robertdowneyjr.', 'chrisevans', 'markruffalo...        josswhedon
# 42274  ['samworthington', 'zoesaldana', 'sigourneywea...      jamescameron
# 42275  ['christianbale', 'michaelcaine', 'heathledger...  christophernolan
# 42276  ['leonardodicaprio', 'josephgordon-levitt', 'e...  christophernolan
# 42277                                                 []               NaN
#
#                  Writer          Producer  \
# 0                   NaN               NaN
# 1          paulmazursky               NaN
# 2             jerrywald               NaN
# 3                   NaN               NaN
# 4          markgrantham               NaN
# ...                 ...               ...
# 42273        josswhedon           stanlee
# 42274      jamescameron      jamescameron
# 42275  christophernolan      charlesroven
# 42276  christophernolan  christophernolan
# 42277               NaN               NaN
#
#                                                 Metadata
# 0                                        daisyasquith
# 1      paulmazursky paulmazursky  michaelontkean rays...
# 2      williamkeighley jerrywald  Comedy ronaldreagan...
# 3                                         gérardblain
# 4      godfreygrayson markgrantham  Drama jillireland...
# ...                                                  ...
# 42273  josswhedon josswhedon stanlee theavengerscolle...
# 42274  jamescameron jamescameron jamescameron avatarc...
# 42275  christophernolan christophernolan charlesroven...
# 42276  christophernolan christophernolan christophern...
# 42277     Odyssey Media Pulser Productions Rogue Stat...
#
# [42278 rows x 21 columns]

# %%
# vectorize the movies' metadata
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
# tokenizes the strings and returns a vector for each string 
count_matrix = count.fit_transform(movies_df["Metadata"])

# calculate cosine similarity between the movies
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# save cosine similarity matrix 
outfile = "metadata_cosineSim"
np.save(outfile, cosine_sim)

# %%
# load metadata cosine similarity matrix 
cosine_sim_loaded = np.load("metadata_cosineSim.npy")

# %%
movies_df = movies_df.reset_index()
movie_titles = movies_df['Title']
indices = pd.Series(movies_df.index, index=movies_df['Title'])

# %% [markdown]
# Content Based recommender method to extract movie recommendations based on input movie title.

# %%
# method concept inspired from kaggle notebook 
def get_recommendations(movie_title):
    movie_index = indices[movie_title]
    sim_scores = list(enumerate(cosine_sim_loaded[movie_index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:20]
    movie_indices = [i[0] for i in sim_scores]
    return list(movie_titles.iloc[movie_indices])

# %% [markdown]
# ### Testing Content Based Recommender

# %% [markdown]
# Testing Content Based Recommenders with a randomly generated lists of 20 movies:
#
# 1. The Magic Lantern
# 2. Dostana
# 3. Illuminata
# 4. Antarctica: A Year on Ice
# 5. Legally Blonde
# 6. The Deal
# 7. Temptation: Confessions of a Marriage Counselor
# 8. Bolero: Dance of Life
# 9. Saint Young Men
# 10. Night Train to Munich
# 11. Julie Darling
# 12. I'll Be There
# 13. Ultrasonic
# 14. The Avengers
# 15. Terminal Invasion
# 16. Pioneer Woman
# 17. Night and Day
# 18. War and Peace
# 19. Dus
# 20. Haunt

# %%
movie_list_1 = ["The Magic Lantern", "Dostana", "Illuminata", "Antarctica: A Year on Ice", "Legally Blonde", 
                "The Deal", "Temptation: Confessions of a Marriage Counselor", "Bolero: Dance of Life",
               "Saint Young Men", "Night Train to Munich", "Julie Darling", "I'll Be There", "Ultrasonic",
               "Cuisine et dépendances", "Terminal Invasion", "Pioneer Woman", "Night and Day", "War and Peace",
               "Dus", "Haunt"]

# %%
for movie in movie_list_1:
    print("Movie: ", movie, " Recommendations: \n")
    print(get_recommendations(movie), "\n")
# Out:
# Movie:  The Magic Lantern  Recommendations:
#
# ['The Human Pyramid', 'The Living Playing Cards', 'The Hilarious Posters', 'The Temptation of St. Anthony', 'The Infernal Cakewalk', 'The Infernal Caldron', 'The Imperceptable Transmutations', 'Tunneling the English Channel', 'The Drawing Lesson', 'The Enchanted Well', 'Between Calais and Dover', 'The Black Imp', 'The Bewitched Inn', "The Astronomer's Dream", 'The Famous Box Trick', 'The Four Troublesome Heads', 'The Haunted Castle', 'The Merry Frolics of Satan', 'An Up-to-Date Conjurer']
#
# Movie:  Dostana  Recommendations:
#
# ['Made For Each Other', "What's Up, Scarlet?", 'Act Like You Love Me', 'Salaam Namaste', 'Bluffmaster!', 'Hello Lonesome', 'Wake Up Sid', 'Wyjazd Integracyjny', "I'm Gonna Explode", 'Kiss the Bride', 'Tulpan', 'White on Rice', 'Dil', 'Mujhse Shaadi Karogi', "Lili's Apron", 'No eres tú, soy yo', 'Mujhse Dosti Karoge!', 'Thank You', 'Bachna Ae Haseeno']
#
# Movie:  Illuminata  Recommendations:
#
# ['Mac', 'Romance & Cigarettes', 'Fading Gigolo', 'She Hate Me', 'Mia Madre', 'Search and Destroy', 'Thirteen Conversations About One Thing', 'Jails, Hospitals & Hip-Hop', 'Sundome', 'Joni', 'Ill Gotten Gains', 'Το γάλα', 'Secret Passage', 'National Geographic American Blackout', 'Yolngu Boy', 'The Luzhin Defence', 'Monday Night Mayhem', 'Box of Moonlight', 'Unstrung Heroes']
#
# Movie:  Antarctica: A Year on Ice  Recommendations:
#
# ['The Carboard Bernini', 'Ride the Divide', 'Red Dot on the Ocean', 'Maidentrip', 'Welcome to Australia', 'Choppertown: The Sinners', 'Vincent: A Life in Color', 'Girls Rock!', 'The Challenge... A Tribute to Modern Art', 'Life After Tomorrow', 'A Perfect Fake', 'Thomas Pynchon: A Journey Into the Mind of P.', 'Home Page', 'Jails, Hospitals & Hip-Hop', 'Arrival of McKinley’s Funeral Train at Canton, Ohio', 'How to Draw a Bunny', 'A League of Ordinary Gentlemen', 'Making the Earth Stand Still', 'Laffghanistan: Comedy Down Range']
#
# Movie:  Legally Blonde  Recommendations:
#
# ['Legally Blonde 2: Red, White & Blonde', 'The Wendell Baker Story', 'Four Christmases', 'Wild', 'Penelope', 'Cruel Intentions', 'Mentor', 'The Last Templar', 'Legally Blondes', 'Tenure', 'Girl', 'Godspell: A Musical Based on the Gospel According to St. Matthew', 'Finding Bliss', 'Life With Mikey', 'Overnight Delivery', 'Dear Eleanor', 'Ordinary World', 'Meadowland', 'Pretty Persuasion']
#
# Movie:  The Deal  Recommendations:
#
# ['Last Exit', 'Office', 'Rege', 'Dustbin Baby', 'Getting Out', 'Red Bear', 'Street Thief', 'Memories of Murder', 'Trash', 'The Least of These', "Manuscripts Don't Burn", 'Tabloid Truth', 'Brothers: The Return', 'Locust', 'Clean Hands', 'Shaitan', 'A Dirty Carnival', 'Apnea', "The Man Who Wouldn't Die"]
#
# Movie:  Temptation: Confessions of a Marriage Counselor  Recommendations:
#
# ['A Madea Christmas', 'The Single Moms Club', 'Madea Goes to Jail', 'Meet the Browns', 'Why Did I Get Married?', "Madea's Witness Protection", 'Why Did I Get Married Too?', 'I Can Do Bad All By Myself', "Madea's Family Reunion", 'Good Deeds', 'The Family That Preys', 'Boo! A Madea Halloween', 'For Colored Girls', 'Diary of a Mad Black Woman', "Daddy's Little Girls", 'Jails, Hospitals & Hip-Hop', 'Sundome', 'Joni', 'Ill Gotten Gains']
#
# Movie:  Bolero: Dance of Life  Recommendations:
#
# ['Crossed Tracks', 'Us Two', 'And Now My Love', 'A Man and a Woman: 20 Years Later', 'All That... for This?!', 'A Man and a Woman', 'Édith et Marcel', 'The Beautiful Story', 'And Now... Ladies and Gentlemen...', 'Les Miserables', "L'aventure c'est l'aventure", 'Itinerary of a Spoiled Child', 'What War May Bring', 'Jails, Hospitals & Hip-Hop', 'Sundome', 'Joni', 'Ill Gotten Gains', 'Το γάλα', 'National Geographic American Blackout']
#
# Movie:  Saint Young Men  Recommendations:
#
# ['Superstar Goofy', 'Creature Comforts', 'Sleeping Betty', 'At the Ends of the Earth', 'Darkness/Light/Darkness', 'The Cat Concerto', 'Bambi Meets Godzilla', "The Fourth Annual 'On Cinema' Oscar Special", 'World Cinema', 'Green Legend Ran', "The First Annual 'On Cinema' Oscar Special", 'Puolin ja toisin', 'Dragon Hill', 'Jungle de Ikou', 'Malice@Doll', 'Кентервильское привидение', 'Mutant Aliens', 'The Saga of Biorn', 'The Employment']
#
# Movie:  Night Train to Munich  Recommendations:
#
# ['Dustbin Baby', 'Getting Out', 'Last Exit', 'The Least of These', 'Apnea', 'The Lady Vanishes', 'Trash', 'Lone Survivor', 'Deported Women of the SS Special Section', 'Morituri', 'Jails, Hospitals & Hip-Hop', 'Sundome', 'Joni', 'Ill Gotten Gains', 'Το γάλα', 'National Geographic American Blackout', 'Yolngu Boy', 'Small Gods', 'You Are Not I']
#
# Movie:  Julie Darling  Recommendations:
#
# ['Raising Jeffrey Dahmer', 'The House of Usher', 'Fear Lives Here', '2AM: The Smiling Man', 'If I Should Die Before I Wake', 'Son of Sam', "H.P. Lovecraft's The Tomb", 'Aashiq Banaya Aapne', '2LDK', 'Solstice', 'Killing Auntie', 'Dustbin Baby', 'Apnea', 'Getting Out', 'Shark Zone', 'Drifter: Henry Lee Lucas', 'The Incite Mill', 'Films to Keep You Awake: The Christmas Tale', 'Phoonk']
#
# Movie:  I'll Be There  Recommendations:
#
# ['Yedyanchi Jatra', 'The Matriarch', "Craig Ferguson: A Wee Bit o' Revolution", 'The Ransom of Red Chief', 'Craig Ferguson: Does This Need to Be Said?', 'Cirque du Soleil: Varekai', 'Hometown Legend', 'The Happiest Millionaire', 'The Trouble with Dee Dee', 'Elizabeth Ekadashi', 'Listen, Darling', 'The Pirate Movie', 'Bandslam', 'Jis Desh Mein Ganga Rehta Hai', 'Radiopiratene', 'Down & Out With The Dolls', 'Uncle P', 'The Singing Nun', 'Our Little Girl']
#
# Movie:  Ultrasonic  Recommendations:
#
# ['Dustbin Baby', 'Getting Out', 'Last Exit', 'The Least of These', 'Apnea', 'Trash', 'Interview with the Assassin', 'Jails, Hospitals & Hip-Hop', 'Sundome', 'Small Gods', 'Joni', 'Ill Gotten Gains', 'You Are Not I', 'Το γάλα', 'National Geographic American Blackout', 'Yolngu Boy', 'The Piano Tuner', 'Little Boy Blue', 'The Ghost and the Whale']
#
# Movie:  Cuisine et dépendances  Recommendations:
#
# ['Family Resemblances', 'Let It Rain', 'Under the Rainbow', 'Look at Me', 'Same Old Song', 'The Matriarch', 'Six in Paris', 'The Taste of Others', 'Le Grand pardon', 'A Woman Is a Woman', 'Joy of Learning', 'Keep Your Right Up', 'The Housekeeper', 'Smoking / No Smoking', "L'Art de la fugue", 'Oh, Woe Is Me', 'King Lear', "Godard's Passion", 'Families']
#
# Movie:  Terminal Invasion  Recommendations:
#
# ['Half -Life', 'Nightmare Code', 'Galerions Rion', 'Children', 'Salad Fingers', 'DeepStar Six', 'The Shadow Men', 'Dark Mountain', 'Creature', 'Watchers', 'The Diabolical', 'Atlantis', 'Hey Happy', 'UFO Abduction', 'Inseminoid', 'Frost', 'Unholy', 'Subject Two', 'Dead Shadows']
#
# Movie:  Pioneer Woman  Recommendations:
#
# ['Then She Found Me', 'Ride', 'The Captains', 'Into the Badlands', 'Arizona Colt Returns', 'Comanche Moon', 'Instructions for a Light & Sound Machine', 'The Fastest Gun Alive', 'Villa Rides', 'The Gunfighter', 'Wild Horse, Wild Ride', 'The Outrage', 'Hud', 'Covert Action', 'The Masked Thief', "Desperado's Duel", 'Mind Meld: Secrets Behind the Voyage of a Lifetime', 'Sweetgrass', 'Trinity And Beyond: The Atomic Bomb Movie']
#
# Movie:  Night and Day  Recommendations:
#
# ["Oki's Movie", "Nobody's Daughter Haewon", 'Hill of Freedom', 'Our Sunhi', 'Right Now, Wrong Then', 'On the Occasion of Remembering the Turning Gate', 'The Day He Arrives', 'Woman Is the Future of Man', 'The Power of Kangwon Province', 'Woman on the Beach', 'Virgin Stripped Bare by Her Bachelors', 'Like You Know It All', 'In Another Country', 'Tale of Cinema', 'The Day a Pig Fell into the Well', "A Good Lawyer's Wife", "The President's Last Bang", 'Jails, Hospitals & Hip-Hop', 'Sundome']
#
# Movie:  War and Peace  Recommendations:
#
# ['A Special Day', 'H.M. Pulham, Esq.', 'Buddha Collapsed Out of Shame', 'Son of a Lion', 'Guernica', 'The Peach Thief', 'The Way to the Stars', 'The Bridges at Toko-Ri', 'A Time to Love and a Time to Die', 'The Duellists', 'April 9th', 'War Arrow', 'Act of Love', '1969', 'The Big Parade', 'Jarhead 3: The Siege', 'Aşk Kırmızı', 'Fires on the Plain', 'Tomorrow Was the War']
#
# Movie:  Dus  Recommendations:
#
# ['Shooters', 'Kalyug', 'Gang War in Milan', 'Syndicate Sadists', 'Graveyard of Honor', 'Shootout at Lokhandwala', 'Main Khiladi Tu Anari', 'Drona', 'Dum Maaro Dum', 'Lahore', 'Evil Behind You', 'Panjaa', '3 Blind Mice', 'Indian', 'Citizen', 'The Heroine', 'Cold Summer of 1953', 'Kaal', 'Fudoh: The New Generation']
#
# Movie:  Haunt  Recommendations:
#
# ['Atrocity', 'The Bucks County Massacre', 'Drive-In Horrorshow', 'The Gerber Syndrome: Il Contagio', 'Raising Jeffrey Dahmer', 'Blood Trails', 'A Nightmare', 'Phoonk', 'Attack of the Sabretooth', "Don't Hug Me I'm Scared 5", "Don't Hug Me, I'm Scared II: Time", 'The Irrefutable Truth About Demons', 'Kotsutsubo', 'Naina', 'Cycling Chronicles: Landscapes the Boy Saw', 'The Bride from Hades', 'Fear Lives Here', 'HazMat', 'Offerings']

# %%
get_recommendations("Dostana")
# Out:
# ['Made For Each Other',
#  "What's Up, Scarlet?",
#  'Act Like You Love Me',
#  'Salaam Namaste',
#  'Bluffmaster!',
#  'Hello Lonesome',
#  'Wake Up Sid',
#  'Wyjazd Integracyjny',
#  "I'm Gonna Explode",
#  'Kiss the Bride',
#  'Tulpan',
#  'White on Rice',
#  'Dil',
#  'Mujhse Shaadi Karogi',
#  "Lili's Apron",
#  'No eres tú, soy yo',
#  'Mujhse Dosti Karoge!',
#  'Thank You',
#  'Bachna Ae Haseeno']

# %%
# testing reccommender results
get_recommendations("Kabhi Khushi Kabhie Gham")
# Out:
# ['Kal Ho Naa Ho',
#  'Student of the Year',
#  'The Matriarch',
#  'Kuch Kuch Hota Hai',
#  'Kabhi Alvida Naa Kehna',
#  'My Name Is Khan',
#  'Ae Dil Hai Mushkil',
#  'The Trouble with Dee Dee',
#  'Elizabeth Ekadashi',
#  'Yedyanchi Jatra',
#  'Chupke Chupke',
#  'Dilwale Dulhania Le Jayenge',
#  'Wrong Side Up',
#  'The Flying Dutchman',
#  'The Living Room of the Nation',
#  'Prince of Broadway',
#  'Return to Me',
#  'Dark Blue Almost Black',
#  'Veer-Zaara']

# %%
# testing reccommender results
get_recommendations("The Avengers")
# Out:
# 42240                          Avengers: Age of Ultron
# 42207              Captain America: The Winter Soldier
# 42216                                          Ant-Man
# 42206                                   Doctor Strange
# 42168                             Thor: The Dark World
# 42248                       Captain America: Civil War
# 42241                                       Iron Man 2
# 42262                                         Iron Man
# 42001                              The Incredible Hulk
# 42235                                             Thor
# 36848                         Marvel One-Shot: Item 47
# 42263                                       Iron Man 3
# 32729            Marvel Studios: Assembling a Universe
# 42243               Captain America: The First Avenger
# 34903    Avengers Confidential: Black Widow & Punisher
# 27752        Iron Man & Captain America: Heroes United
# 42272                                         Deadpool
# 33212                   Iron Man & Hulk: Heroes United
# 36165                                        Team Thor
# Name: Title, dtype: object

# %%
# testing reccomender results 
get_recommendations("The Dark Knight")
# Out:
# 42265                 The Dark Knight Rises
# 42249                         Batman Begins
# 40136            Batman: Under the Red Hood
# 42134                          The Prestige
# 39268             Batman: Assault on Arkham
# 39673                             Following
# 41663                        Batman Returns
# 26688                 The Holcroft Covenant
# 42276                             Inception
# 41942                               Dunkirk
# 6549                               Shooters
# 40206              Batman: The Killing Joke
# 35510          Batman & Mr. Freeze: SubZero
# 2157               The Last Desperate Hours
# 36562                             Doodlebug
# 2143                        Evil Behind You
# 7085                   Atom Man vs Superman
# 42245    Batman v Superman: Dawn of Justice
# 14592                      Chicago Overcoat
# Name: Title, dtype: object

# %%
# testing reccomender results 
get_recommendations("Harry Potter and the Philosopher's Stone")
# Out:
# 42212              Harry Potter and the Chamber of Secrets
# 42190               Harry Potter and the Half-Blood Prince
# 42203                  Harry Potter and the Goblet of Fire
# 42217             Harry Potter and the Prisoner of Azkaban
# 42198            Harry Potter and the Order of the Phoenix
# 42201         Harry Potter and the Deathly Hallows: Part 1
# 42220         Harry Potter and the Deathly Hallows: Part 2
# 1432                                           Bhoot Unkle
# 1438                                 Jill And Joy's Winter
# 7643                           A Journey Through Fairyland
# 16207                                 Wow! A Talking Fish!
# 41789    Percy Jackson & the Olympians: The Lightning T...
# 7099                                Puff, the Magic Dragon
# 7787                                        All She Wishes
# 863                           The Wonderful Ice Cream Suit
# 3761                                     Der Struwwelpeter
# 40224                                          Hocus Pocus
# 34825                                   Halloweentown High
# 36281                                        Halloweentown
# Name: Title, dtype: object

# %%
# testing reccomender results 
get_recommendations("Tangled")
# Out:
# 39802                                   Tangled Ever After
# 41418                            The Princess and the Frog
# 5239                                           Cheburashka
# 8391                    VeggieTales: Josh and the Big Wall
# 12697    VeggieTales: Minnesota Cuke and the Search for...
# 41439                                      Sleeping Beauty
# 41551                                            Enchanted
# 41697                                                 Bolt
# 1351                                      Green Legend Ran
# 1438                                 Jill And Joy's Winter
# 6489                                           Dragon Hill
# 9987                                           Malice@Doll
# 12124                            Кентервильское привидение
# 36224                                              Tin Toy
# 35376                                          Red's Dream
# 37608                                             Luxo Jr.
# 15898                                        A Flying Ship
# 24332                          The Princess and the Goblin
# 30159                                    Creature Comforts
# Name: Title, dtype: object

# %%
# testing reccomender results 
get_recommendations("Cinderella")
# Out:
# 39930     Ever After: A Cinderella Story
# 35993        Three Wishes for Cinderella
# 41439                    Sleeping Beauty
# 31032        The Cave of the Golden Rose
# 10532                        Aşk Kırmızı
# 38847    Cinderella III: A Twist in Time
# 10023          Cirque du Soleil: Varekai
# 15161                More Than a Miracle
# 13308        Prince and the Evening Star
# 39026    Cinderella II: Dreams Come True
# 836           Jails, Hospitals & Hip-Hop
# 1076                             Sundome
# 1432                         Bhoot Unkle
# 1438               Jill And Joy's Winter
# 2017                                Joni
# 2520                    Ill Gotten Gains
# 3760                             Το γάλα
# 4304                  Counting Backwards
# 7643         A Journey Through Fairyland
# Name: Title, dtype: object

# %% [markdown]
# ### **Collaborative Filtering**

# %%
# read in movie ratings 
ratings_df = pd.read_csv('Movies Data/ratings.csv')

# rename columns
ratings_df = ratings_df.rename(columns={"userId": "User ID", 
                                        "movieId": "Movie ID", 
                                        "timestamp": "Timestamp"})

# %%
ratings_df
# Out:
#           User ID  Movie ID  rating   Timestamp
# 0               1       110     1.0  1425941529
# 1               1       147     4.5  1425942435
# 2               1       858     5.0  1425941523
# 3               1      1221     5.0  1425941546
# 4               1      1246     5.0  1425941556
# ...           ...       ...     ...         ...
# 26024284   270896     58559     5.0  1257031564
# 26024285   270896     60069     5.0  1257032032
# 26024286   270896     63082     4.5  1257031764
# 26024287   270896     64957     4.5  1257033990
# 26024288   270896     71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
# check for null values
ratings_df.isnull().any()
# Out:
# User ID      False
# Movie ID     False
# rating       False
# Timestamp    False
# dtype: bool

# %%
# !pip install scikit-surprise
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
from surprise import dump
# Out:
# Requirement already satisfied: scikit-surprise in /home/ashna/anaconda3/lib/python3.8/site-packages (1.1.1)
# Requirement already satisfied: joblib>=0.11 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (0.16.0)
# Requirement already satisfied: numpy>=1.11.2 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (1.5.0)
# Requirement already satisfied: six>=1.10.0 in /home/ashna/anaconda3/lib/python3.8/site-packages (from scikit-surprise) (1.15.0)

# %%
reader = Reader()

# %%
data = Dataset.load_from_df(ratings_df[['User ID', 'Movie ID', 'rating']], reader)
algo = SVD()
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.7965  0.7962  0.7956  0.7962  0.7960  0.7961  0.0003
# MAE (testset)     0.6023  0.6025  0.6019  0.6023  0.6021  0.6022  0.0002
# Fit time          685.16  694.63  693.42  692.81  695.55  692.31  3.70
# Test time         57.71   58.90   49.77   49.97   46.38   52.54   4.88
# {'test_rmse': array([0.79654272, 0.79619573, 0.79561253, 0.79622099, 0.79598232]),
#  'test_mae': array([0.60225976, 0.60245458, 0.60187422, 0.6023217 , 0.6021279 ]),
#  'fit_time': (685.1593697071075,
#   694.6251404285431,
#   693.4244229793549,
#   692.8122618198395,
#   695.5460493564606),
#  'test_time': (57.705753564834595,
#   58.895099401474,
#   49.7657413482666,
#   49.96788167953491,
#   46.383798360824585)}

# %%
training_data = data.build_full_trainset()
algo.fit(training_data)

# %%
algo.predict(1, 302, 3).est

# check if the algorithm outputs

# %%
# Dump algorithm to save 
file_name = "SVD_model_ex"
dump.dump(file_name, algo=algo)

# %% [markdown]
# #### Reload Collaboraitve Filtering Model

# %%
# reload algorithm
from surprise import dump
file_name = "SVD_model_ex"
_, loaded_algo = dump.load(file_name)

# %% [markdown]
# Surprise package predict method takes in:
# - uid = user ID
# - iid = item id
# - rui = true rating -- optional

# %% [markdown]
# ### Testing Collaborative Filtering Model

# %% [markdown]
# Testing Collaborative Filtering Recommender System with a randomly generated list of 20 movies:
#
# 1. The Wild and the Innocent
# 2. The Wrecking Crew
# 3. Animation Runner Kuromi
# 4. Rage of Angels: The Story Continues
# 5. Ivko’s Feast
# 6. Red-Headed Woman
# 7.  Elles
# 8. Return to Me
# 9. Grand Piano
# 10. Ellie Parker
# 11.  Kiss the Girls
# 12. Love on the Air
# 13. The Insect Woman
# 14. Dark Angel
# 15. Pastorale
# 16. Taken
# 17. Smokey Bites the Dust
# 18. Nobody Knows Sex
# 19. Yellow Sky
# 20. Viva Cuba

# %%
movie_list_2 = ["The Wild and the Innocent", "The Wrecking Crew", "Animation Runner Kuromi", 
                "Rage of Angels: The Story Continues", "Ivko’s Feast", 
                "Red-Headed Woman", "Elles", "Return to Me", "Grand Piano", "Ellie Parker", 
                "Kiss the Girls", "Love on the Air",
               "The Insect Woman", "Dark Angel", "Pastorale", "Taken", "Smokey Bites the Dust",
               "Nobody Knows Sex", "Yellow Sky", "Viva Cuba"]

movie_list2_ids = [140585, 130351, 157809, 126004, 158599, 49752, 100529, 3512, 109472,
                   48584, 1620, 158902, 82747, 57873, 154606, 59369, 157174, 172619, 25948, 59302]

user_ids = [12531, 250401, 208804, 87908, 140719, 47314, 81525, 211331, 186383, 24025,
        90738, 115203, 81172, 64000, 149766, 93683, 269917, 240428, 82371, 87842]

# %%
for movie, movie_id, user_id in zip(movie_list_2, movie_list2_ids, user_ids):
    print("Movie:", movie, "\nUser ID:", user_id)
    print("Predicted User Rating:", loaded_algo.predict(movie_id, user_id).est, "\n")
# Out:
# Movie: The Wild and the Innocent
# User ID: 12531
# Predicted User Rating: 3.5116808152338614
#
# Movie: The Wrecking Crew
# User ID: 250401
# Predicted User Rating: 3.4704278519498133
#
# Movie: Animation Runner Kuromi
# User ID: 208804
# Predicted User Rating: 4.225786241394033
#
# Movie: Rage of Angels: The Story Continues
# User ID: 87908
# Predicted User Rating: 3.4969149552792893
#
# Movie: Ivko’s Feast
# User ID: 140719
# Predicted User Rating: 4.024811363191137
#
# Movie: Red-Headed Woman
# User ID: 47314
# Predicted User Rating: 3.515199356194008
#
# Movie: Elles
# User ID: 81525
# Predicted User Rating: 3.7204387294337455
#
# Movie: Return to Me
# User ID: 211331
# Predicted User Rating: 2.6418320205925925
#
# Movie: Grand Piano
# User ID: 186383
# Predicted User Rating: 3.4307908184830467
#
# Movie: Ellie Parker
# User ID: 24025
# Predicted User Rating: 3.719141306480401
#
# Movie: Kiss the Girls
# User ID: 90738
# Predicted User Rating: 3.936288919445495
#
# Movie: Love on the Air
# User ID: 115203
# Predicted User Rating: 3.746430022918287
#
# Movie: The Insect Woman
# User ID: 81172
# Predicted User Rating: 3.7242942577705413
#
# Movie: Dark Angel
# User ID: 64000
# Predicted User Rating: 3.5954838002027025
#
# Movie: Pastorale
# User ID: 149766
# Predicted User Rating: 2.881334400818809
#
# Movie: Taken
# User ID: 93683
# Predicted User Rating: 3.6714444488629874
#
# Movie: Smokey Bites the Dust
# User ID: 269917
# Predicted User Rating: 3.6656844238516277
#
# Movie: Nobody Knows Sex
# User ID: 240428
# Predicted User Rating: 3.529135604606165
#
# Movie: Yellow Sky
# User ID: 82371
# Predicted User Rating: 3.915510501289696
#
# Movie: Viva Cuba
# User ID: 87842
# Predicted User Rating: 3.5873809799049363

# %% [markdown]
# ### Hybrid Recommender combining Content Based and Collaborative Filtering Models

# %% [markdown]
# Hybrid Recommender combining content based model and collaborative filtering model. Going to input the User ID and title of the movie and return top 20 movies that are similar based on both the metadata of the input movie and the user's preferences and predicted ratings of those movies.

# %%
movies_df
# Out:
#        index          ID    IMDB ID              Title  \
# 0          0      461257  tt6980792           Queerama
# 1          1       92323  tt0081758    Willie and Phil
# 2          2      114838  tt0029949        Brother Rat
# 3          3      264723  tt0070580         Le pélican
# 4          4       88061  tt0055459  So Evil, So Young
# ...      ...         ...        ...                ...
# 42273  42273       24428  tt0848228       The Avengers
# 42274  42274       19995  tt0499549             Avatar
# 42275  42275         155  tt0468569    The Dark Knight
# 42276  42276       27205  tt1375666          Inception
# 42277  42277  2014-01-01          0                NaN
#
#                     Collection  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 42273    theavengerscollection
# 42274         avatarcollection
# 42275  thedarkknightcollection
# 42276                      NaN
# 42277                      NaN
#
#                                                   Genres Language  \
# 0                                                     []       en
# 1                                                     []       en
# 2                                             ['Comedy']       en
# 3                                                     []       en
# 4                                              ['Drama']       en
# ...                                                  ...      ...
# 42273         ['Science Fiction', 'Action', 'Adventure']       en
# 42274  ['Action', 'Adventure', 'Fantasy', 'Science Fi...       en
# 42275           ['Drama', 'Action', 'Crime', 'Thriller']       en
# 42276  ['Action', 'Thriller', 'Science Fiction', 'Mys...       en
# 42277  ['Odyssey Media', 'Pulser Productions', 'Rogue...     82.0
#
#       Spoken Languages Release Date  Runtime  ...  \
# 0               ['en']   2017-06-09     75.0  ...
# 1                   []   1980-08-15    115.0  ...
# 2               ['en']   1938-10-29     87.0  ...
# 3                   []   1974-02-06     83.0  ...
# 4               ['en']   1963-01-01     77.0  ...
# ...                ...          ...      ...  ...
# 42273           ['en']   2012-04-25    143.0  ...
# 42274     ['en', 'es']   2009-12-10    162.0  ...
# 42275     ['en', 'zh']   2008-07-16    152.0  ...
# 42276           ['en']   2010-07-14    148.0  ...
# 42277               []          NaN      NaN  ...
#
#                                  Production Countries Popularity Rating  \
# 0                                  ['United Kingdom']          0.163015
# 1                                                  []          0.326500
# 2                        ['United States of America']          0.174691
# 3                                                  []          0.000115
# 4                                                  []          0.001662
# ...                                               ...               ...
# 42273                    ['United States of America']         89.887648
# 42274  ['United States of America', 'United Kingdom']        185.070892
# 42275  ['United Kingdom', 'United States of America']        123.167259
# 42276  ['United Kingdom', 'United States of America']         29.108149
# 42277                                             NaN               NaN
#
#       Vote Count  Vote Average  \
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ...          ...           ...
# 42273    12000.0           7.4
# 42274    12114.0           7.2
# 42275    12269.0           8.3
# 42276    14075.0           8.1
# 42277        NaN           NaN
#
#                                                 Keywords  \
# 0                                                     []
# 1                                                     []
# 2                               ['basedonplayormusical']
# 3                                                     []
# 4                            ['prison', "women'sprison"]
# ...                                                  ...
# 42273  ['newyork', 'shield', 'marvelcomic', 'superher...
# 42274  ['cultureclash', 'future', 'spacewar', 'spacec...
# 42275  ['dccomics', 'crimefighter', 'secretidentity',...
# 42276  ['lossoflover', 'dream', 'kidnapping', 'sleep'...
# 42277                                                 []
#
#                                                     Cast          Director  \
# 0                                                     []      daisyasquith
# 1       ['michaelontkean', 'raysharkey', 'margotkidder']      paulmazursky
# 2      ['ronaldreagan', 'janewyman', 'priscillalane',...   williamkeighley
# 3                                                     []       gérardblain
# 4      ['jillireland', 'ellenpollock', 'joanhaythorne...    godfreygrayson
# ...                                                  ...               ...
# 42273  ['robertdowneyjr.', 'chrisevans', 'markruffalo...        josswhedon
# 42274  ['samworthington', 'zoesaldana', 'sigourneywea...      jamescameron
# 42275  ['christianbale', 'michaelcaine', 'heathledger...  christophernolan
# 42276  ['leonardodicaprio', 'josephgordon-levitt', 'e...  christophernolan
# 42277                                                 []               NaN
#
#                  Writer          Producer  \
# 0                   NaN               NaN
# 1          paulmazursky               NaN
# 2             jerrywald               NaN
# 3                   NaN               NaN
# 4          markgrantham               NaN
# ...                 ...               ...
# 42273        josswhedon           stanlee
# 42274      jamescameron      jamescameron
# 42275  christophernolan      charlesroven
# 42276  christophernolan  christophernolan
# 42277               NaN               NaN
#
#                                                 Metadata
# 0                                        daisyasquith
# 1      paulmazursky paulmazursky  michaelontkean rays...
# 2      williamkeighley jerrywald  Comedy ronaldreagan...
# 3                                         gérardblain
# 4      godfreygrayson markgrantham  Drama jillireland...
# ...                                                  ...
# 42273  josswhedon josswhedon stanlee theavengerscolle...
# 42274  jamescameron jamescameron jamescameron avatarc...
# 42275  christophernolan christophernolan charlesroven...
# 42276  christophernolan christophernolan christophern...
# 42277     Odyssey Media Pulser Productions Rogue Stat...
#
# [42278 rows x 22 columns]

# %%
# read in movies ID map csv file
movies_ID_map = pd.read_csv("movies_ID_map.csv")
movies_ID_map
# Out:
#                    Title      ID  Movie ID
# 0               Queerama  461257    176279
# 1        Willie and Phil   92323    112577
# 2            Brother Rat  114838    112548
# 3             Le pélican  264723    112510
# 4      So Evil, So Young   88061    112467
# ...                  ...     ...       ...
# 42272           Deadpool  293660    122904
# 42273       The Avengers   24428     89745
# 42274             Avatar   19995     72998
# 42275    The Dark Knight     155     58559
# 42276          Inception   27205     79132
#
# [42277 rows x 3 columns]

# %%
def hybrid_recommender(userID, title):
    index = indices[title]
    tmdbId = movies_ID_map.loc[movies_ID_map["Title"] == title]['ID']
    movie_id = movies_ID_map.loc[movies_ID_map["Title"] == title]['Movie ID']
    
    # take top 25 movies based on similarity scores to calculate the vote of the 60th percentile movie
    # then calculate the weighted rating of each movie using IMDB formula 
    sim_scores = list(enumerate(cosine_sim_loaded[int(index)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:21]
    similar_movie_indices = [i[0] for i in sim_scores]
    
    movies = movies_df.iloc[similar_movie_indices][['Title', 'Vote Count', 'Vote Average', 'ID']]
    similar_movies_IDs = list(map(int, movies["ID"].values))

    for ID, index in zip(similar_movies_IDs, similar_movie_indices):
        movieID = int(movies_ID_map.loc[movies_ID_map["ID"] == ID]['Movie ID'])
        est_rating = loaded_algo.predict(userID, movieID).est
        movies.loc[index, "est"] = est_rating
        
    movies = movies.sort_values('est', ascending=False)
    return movies

# %% [markdown]
# ### Testing Hybrid Recommender Model

# %% [markdown]
# Testing Hybrid Recommender System with a randomly generated lists of 20 movies:
#
# 1. A Rumor of Angels
# 2. Rab Ne Bana Di Jodi
# 3. The Canyons
# 4. Death of a Ghost Hunter
# 5. Om Shanti Om
# 6. Force Majeure
# 7. Cuckoo in a Dark Forest
# 8. One Man Band
# 9. She's The Man
# 10. House of Strangers
# 11.  Since You Went Away
# 12. Nymph
# 13. Trench Road
# 14. MP3: Mera Pehla Pehla Pyaar
# 15. Picture This
# 16. Belizaire the Cajun
# 17. Captain Midnight
# 18. The BFG
# 19. Menace II Society
# 20. Gringo: The Dangerous Life of John McAfee

# %%
movie_list_3 = ["A Rumor of Angels", "Rab Ne Bana Di Jodi", "The Canyons", 
                "Death of a Ghost Hunter", "Om Shanti Om", "Force Majeure",
                 "Cuckoo in a Dark Forest", "One Man Band", "She's the Man", "House of Strangers", 
                "Since You Went Away", "Nymph", "Trench Road", "MP3: Mera Pehla Pehla Pyaar", "Picture This", 
                "Belizaire the Cajun", "Captain Midnight",
               "The BFG", "Menace II Society", "Gringo: The Dangerous Life of John McAfee"]

user_ids_3 = [191710, 73828, 144404, 184014, 131044, 257082, 112273, 55027, 146087, 121670,
              34292, 12765, 114367, 260974, 65680, 264587, 180120, 245401, 52523, 165159]

# %%
for user_id, movie in zip(user_ids_3, movie_list_3):
    print("Movie:", movie, "\nUser ID:", user_id)
    movies = hybrid_recommender(user_id, movie)
    print("Suggested Movies and Predicted User Ratings: \n")
    for movie, rating in zip(list(movies["Title"]), list(movies["est"])):
        print(movie, rating)
    print("\n")
# Out:
# Movie: A Rumor of Angels
# User ID: 191710
# Suggested Movies and Predicted User Ratings:
#
# Dean Spanley 5.0
# Joni 4.873432635751732
# Το γάλα 4.873106312457637
# Yolngu Boy 4.803022084966903
# Suicide Kings 4.763744698194322
# Local Color 4.753844496426946
# Ice Men 4.753363993380459
# Playing for Time 4.733662801253455
# Fixing Frank 4.7104122419209515
# Holly 4.698970113368664
# How About You... 4.688568808719002
# Foxtrot 4.655837869682314
# Room 314 4.648421813144384
# National Geographic American Blackout 4.632371606456225
# The Trouble with Dee Dee 4.579154969872186
# Jails, Hospitals & Hip-Hop 4.516912213698248
# Gringuito 4.488776958066487
# Sundome 4.461002412857885
# Went to Coney Island on a Mission from God... Be Back by Five 4.414132257169495
# Ill Gotten Gains 4.239412349372494
#
#
# Movie: Rab Ne Bana Di Jodi
# User ID: 73828
# Suggested Movies and Predicted User Ratings:
#
# The Trouble with Dee Dee 3.5306654739369456
# All The Days Before Tomorrow 3.431429603275943
# My Name Is Khan 3.3950901315684705
# Dilwale Dulhania Le Jayenge 3.372624832809697
# A perfect match 3.3402212470659047
# The Bridal Party in Hardanger 3.3246858327125506
# Dil To Pagal Hai 3.3193799174203766
# Band Baaja Baaraat 3.304878181386562
# Veer-Zaara 3.3034983656501105
# Silja - nuorena nukkunut 3.26152136567691
# Boynton Beach Club 3.2569672499981834
# Aşk Kırmızı 3.223956684761458
# Pyaar Ke Side Effects 3.1926050044249985
# Jab Tak Hai Jaan 3.1813625207824474
# Babycakes 3.145463619053534
# The Matriarch 3.1225242680987746
# Om Shanti Om 3.122104597769397
# Chalte Chalte 2.976697250028002
# Mujhse Dosti Karoge! 2.8921358884532533
# Divine Intervention 2.624808707521348
#
#
# Movie: The Canyons
# User ID: 144404
# Suggested Movies and Predicted User Ratings:
#
# Year of the Jellyfish 3.758203563132076
# The Ghost and the Whale 3.630999381390577
# Το γάλα 3.613389299002824
# Apnea 3.559915108744635
# Dustbin Baby 3.554439429329637
# National Geographic American Blackout 3.5318173548033833
# Yolngu Boy 3.445574599545306
# Die Totale Therapie 3.4343570394004463
# Joni 3.420213656918446
# Cheeky 3.340808526051683
# Getting Out 3.3326057884491505
# Forever Mine 3.2553204145103916
# Jails, Hospitals & Hip-Hop 3.121357560537309
# Sundome 3.0198259032891652
# Touch 2.9222147656045916
# Affliction 2.893750613420015
# American Gigolo 2.8823199876326293
# Ill Gotten Gains 2.836174896856685
# Holy Smoke! 2.7563109804717247
# Dying of the Light 2.375435983532687
#
#
# Movie: Death of a Ghost Hunter
# User ID: 184014
# Suggested Movies and Predicted User Ratings:
#
# Dustbin Baby 3.5969496857365106
# 404: Error Not Found 3.375014530281157
# Getting Out 3.351695283802662
# Kalyug 3.337444594897808
# 2AM: The Smiling Man 3.3187675127894307
# Rege 3.305416435984059
# Apartment 18 3.293917977781911
# Dangerous Company 3.293178641768842
# Supermarket 3.2822021083756123
# The Living Ghost 3.2781194162156915
# Fear Lives Here 3.2641867280412598
# Last Exit 3.2498712979825553
# The Least of These 3.2102480113425726
# Evil Behind You 3.192554820530385
# Dreamkiller 3.175279308144207
# Apnea 3.1723861202797936
# The Ghost and the Whale 3.1616202278686716
# The Cabining 3.1608923425947237
# Paranormal Activity: Tokyo Night 3.083388833221886
# The Frankenstein Syndrome 2.7999158669009514
#
#
# Movie: Om Shanti Om
# User ID: 131044
# Suggested Movies and Predicted User Ratings:
#
# The Trouble with Dee Dee 2.8901527413947696
# Yedyanchi Jatra 2.322425845364937
# Main Hoon Na 2.29048055731416
# Rab Ne Bana Di Jodi 2.250620544521596
# The Matriarch 2.19106358973057
# Take Care 2.1330106332045964
# Silja - nuorena nukkunut 2.1044842930594747
# Elizabeth Ekadashi 2.0715281915684556
# My Name Is Khan 2.029960822363639
# Bran Nue Dae 2.0252023455752517
# A perfect match 1.8555254463224573
# Room 314 1.8111909306360627
# Babycakes 1.7697004384523247
# All The Days Before Tomorrow 1.724982847324612
# Dilwale Dulhania Le Jayenge 1.618289401651027
# Chalte Chalte 1.4785403106906116
# Boynton Beach Club 1.438779928136318
# Divine Intervention 1.1380430078680197
# Aşk Kırmızı 1.1073212899606535
# The Bridal Party in Hardanger 1.0
#
#
# Movie: Force Majeure
# User ID: 257082
# Suggested Movies and Predicted User Ratings:
#
# The Living Room of the Nation 3.7853026965869065
# Involuntary 3.7768909635603105
# Elizabeth Ekadashi 3.5473214875104824
# Το γάλα 3.4897969376934617
# The First Annual 'On Cinema' Oscar Special 3.446128073623019
# World Cinema 3.429088238271738
# The Fourth Annual 'On Cinema' Oscar Special 3.3997400279779724
# When Comedy Went to School 3.3625248673026693
# Joni 3.3429332902641953
# Prince of Broadway 3.283796875677807
# Puolin ja toisin 3.2435734657694857
# The Guitar Mongoloid 3.23556908682188
# The Trouble with Dee Dee 3.2218497876162333
# Sundome 3.2048497059226744
# The Flying Dutchman 3.1878510471843664
# New Year 3.075020886506906
# Jails, Hospitals & Hip-Hop 3.060912737379543
# Yedyanchi Jatra 3.048075845171367
# The Matriarch 3.0038746451271146
# Ill Gotten Gains 2.856745119256504
#
#
# Movie: Cuckoo in a Dark Forest
# User ID: 112273
# Suggested Movies and Predicted User Ratings:
#
# Buddha Collapsed Out of Shame 3.6090959588138984
# Chosin 3.488514882045328
# Yolngu Boy 3.4553371905527435
# The Father of a Soldier 3.4369849850665295
# Το γάλα 3.419494293382463
# April 9th 3.336021424004374
# My Honor Was Loyalty 3.33352343779367
# Tears of April 3.3203260535637966
# Four Winds of Heaven 3.300209153700808
# The Diary of an Unknown Soldier 3.2794398111280114
# National Geographic American Blackout 3.2395904302338234
# The Fallen 3.213184346954008
# Londra chiama Polo Nord 3.2039633969532244
# Son of a Lion 3.1486600028983087
# Joni 3.1121168375600123
# Sundome 3.0844543552353247
# Jails, Hospitals & Hip-Hop 3.0386050361302734
# Jarhead 3: The Siege 2.7875142950007596
# Ill Gotten Gains 2.6495858506993764
# 1969 2.5510457683400865
#
#
# Movie: One Man Band
# User ID: 55027
# Suggested Movies and Predicted User Ratings:
#
# Geri's Game 4.138895589481891
# La luna 3.9175722131049433
# Knick Knack 3.682832458235056
# Cheburashka 3.6812213275129273
# Luxo Jr. 3.67172770114127
# Tick Tock Tale 3.6570454985216005
# BURN·E 3.628091247722078
# Boundin' 3.6093476716027584
# Day & Night 3.594305000660513
# Your Friend the Rat 3.5479164625122457
# Tin Toy 3.513099134876933
# The Tale of Tsar Saltan 3.5114438893160997
# VeggieTales: Minnesota Cuke and the Search for Samson's Hairbrush 3.4795630748026114
# VeggieTales: Sheerluck Holmes and the Golden Ruler 3.45232923947808
# VeggieTales: Josh and the Big Wall 3.4511785393091126
# Jack-Jack Attack 3.4039523756423513
# Red's Dream 3.337041364648912
# George & A.J. 3.1008834601626014
# Air Mater 3.0183222722594216
# Mater and the Ghostlight 2.8773596026856803
#
#
# Movie: She's the Man
# User ID: 146087
# Suggested Movies and Predicted User Ratings:
#
# Elizabeth Ekadashi 3.4245356289016162
# A Little Romance 3.216341384743859
# The Bad Mother's Handbook 3.186315189019709
# The Young Visiters 3.117457217759562
# The Ransom of Red Chief 3.112909534676859
# Alice Upside Down 3.109796712273845
# Hometown Legend 3.086336258696199
# The Trouble with Dee Dee 3.075568136919517
# The Card 2.9864513936087858
# Babycakes 2.9679145294803324
# Little Miss Marker 2.920128212056946
# The Matriarch 2.918670879790324
# Threesome 2.8804202202094062
# Her Best Move 2.854345590421472
# Yedyanchi Jatra 2.8113200971142165
# I Love You, I Love You Not 2.768313562675156
# Angus 2.6322950376065224
# Jis Desh Mein Ganga Rehta Hai 2.5551744176306794
# Love Don't Cost a Thing 2.3987709650660203
# MVP: Most Valuable Primate 2.202244851320594
#
#
# Movie: House of Strangers
# User ID: 121670
# Suggested Movies and Predicted User Ratings:
#
# Cleopatra 4.111552080520917
# People Will Talk 4.061661867501563
# Five Star Final 3.9834161427758046
# Somewhere in the Night 3.9246901876621703
# The Whole Town's Talking 3.8696565376259486
# Manuscripts Don't Burn 3.861055924666943
# Two Seconds 3.8498642992978085
# The Widow From Chicago 3.823620624142341
# Manhattan Melodrama 3.7977547617890273
# Our Vines Have Tender Grapes 3.6999125385581046
# Dragonwyck 3.6564303176476627
# A Letter to Three Wives 3.6253023928896746
# The Hatchet Man 3.576402724927321
# Rege 3.5552105357539814
# The Last Gangster 3.545374904842784
# I Am the Law 3.5364119915348917
# The Honey Pot 3.5187935439133358
# The Barefoot Contessa 3.486323403483658
# Last Exit 3.443997421072002
# The Black Lapp 3.4319222104017455
#
#
# Movie: Since You Went Away
# User ID: 34292
# Suggested Movies and Predicted User Ratings:
#
# Manhattan Melodrama 4.118740173778956
# Gone with the Wind 4.057160602626248
# Nothing Sacred 4.056462558713853
# Spellbound 4.04804890037869
# Dinner at Eight 3.9516542608495415
# Portrait of Jennie 3.9343494841275297
# The Paradine Case 3.8840602061422405
# The Lost Squadron 3.833695936022914
# What Price Hollywood? 3.783421664325184
# The Animal Kingdom 3.702156458574221
# Young Bride 3.696038634446886
# Duel in the Sun 3.6591355128111642
# Bird of Paradise 3.651189682180679
# Intermezzo: A Love Story 3.616850698421822
# David Copperfield 3.580264447865563
# The Garden of Allah 3.5433391505934
# Thirteen Women 3.4889171119540014
# Made for Each Other 3.4417295261683707
# Indiscretion of an American Wife 3.254178742893667
# Christopher Strong 3.053400305044536
#
#
# Movie: Nymph
# User ID: 12765
# Suggested Movies and Predicted User Ratings:
#
# Don't Hug Me, I'm Scared 4.121728763565574
# Bhoothnath Returns 4.1077790920060036
# The Rift 3.9840945499407026
# Ghost Chase 3.956044508017716
# Merlin's Shop of Mystical Wonders 3.925022269203171
# One Night in A City 3.8946221004831796
# Drive-In Horrorshow 3.829667969729326
# The Flaying 3.824402499784697
# Unlucky Charms 3.795806259537524
# Atrocity 3.7531791068795743
# The Bucks County Massacre 3.731653078923581
# The Gerber Syndrome: Il Contagio 3.7298468333191974
# Out of Mind: The Stories of H.P. Lovecraft 3.723559631186952
# Le Papillon Fantastique 3.7228462974333683
# Lust in the Mummy's Tomb 3.7151233364580514
# Arundhati 3.595084374403574
# Zone of the Dead 3.5733342847983445
# Lost in New York 3.5501046849847957
# The Drownsman 3.2696143792780625
# The Coven 2.993475307061208
#
#
# Movie: Trench Road
# User ID: 114367
# Suggested Movies and Predicted User Ratings:
#
# Scabbard Samurai 3.6568656591477464
# Το γάλα 3.637190524806423
# The First Annual 'On Cinema' Oscar Special 3.6214339468708783
# Lampaansyöjät 3.610847832886777
# Yolngu Boy 3.591092734579841
# The Cherry Orchard 3.5478861514138758
# Puolin ja toisin 3.54299370168022
# Buddies 3.538666335310508
# World Cinema 3.5150975850561443
# How Not to Work & Claim Benefits... (and Other Useful Information for Wasters) 3.504745609570026
# The Matriarch 3.471718701248628
# Doc Martin and the Legend of the Cloutie 3.4391307377287603
# The Fourth Annual 'On Cinema' Oscar Special 3.4271773531276484
# National Geographic American Blackout 3.3899978096457795
# Sundome 3.3806527521810135
# Joni 3.3793680667374466
# The House of Fools 3.3585052577645707
# Mina Tannenbaum 3.2805013068385813
# Jails, Hospitals & Hip-Hop 3.2552452284153146
# Ill Gotten Gains 3.1102369192126202
#
#
# Movie: MP3: Mera Pehla Pehla Pyaar
# User ID: 260974
# Suggested Movies and Predicted User Ratings:
#
# The Bridal Party in Hardanger 3.802685039180024
# Time Please 3.762458524689054
# Counting Backwards 3.755928057242803
# Tum Bin 3.7472704465937636
# Το γάλα 3.713362463871015
# La cartomancienne 3.7081120460218946
# Tear This Heart Out 3.6796764084446147
# A Small September Affair 3.644115970270351
# Room 314 3.6043113837002947
# Yolngu Boy 3.579408962375156
# Maria Chapdelaine 3.5688172366967277
# Aşk Kırmızı 3.528752309518734
# Silja - nuorena nukkunut 3.525166915298924
# Divine Intervention 3.4928271314527515
# National Geographic American Blackout 3.4644172298361093
# Joni 3.445713939578286
# Sundome 3.3339166097494934
# Lakeer - Forbidden Lines 3.3057213443775737
# Jails, Hospitals & Hip-Hop 3.0250443798857307
# Ill Gotten Gains 3.0075734107430105
#
#
# Movie: Picture This
# User ID: 65680
# Suggested Movies and Predicted User Ratings:
#
# Assume the Position with Mr. Wuhl 4.119026910202774
# Living with the Fosters 4.044979481695102
# The Second Annual 'On Cinema' Oscar Special 4.030038625230017
# Człowiek z M-3 4.009857127251007
# Медведь 4.002209798128277
# Down & Out With The Dolls 3.9787928563043056
# The Third Annual 'On Cinema' Oscar Special 3.9356639511283666
# World Cinema 3.933110704433642
# The Fourth Annual 'On Cinema' Oscar Special 3.9012395307503964
# Puckoon 3.8525314581817938
# Made For Each Other 3.8195603874039383
# Questi fantasmi 3.7846045323925264
# The First Annual 'On Cinema' Oscar Special 3.7562504578937945
# 3 Simoa 3.7516739137042165
# Fragments of an Alms-Film 3.6765260452011717
# Puolin ja toisin 3.656091623638209
# Radiopiratene 3.635214495153116
# Rules of Single Life 3.5783615457754117
# Jungle 2 Jungle 3.5246809567654527
# Million Dollar Mystery 3.387308762189576
#
#
# Movie: Belizaire the Cajun
# User ID: 264587
# Suggested Movies and Predicted User Ratings:
#
# Princess Yang Kwei Fei 4.103883712430243
# Senso 4.055281719760819
# Good Men, Good Women 3.9890212105913165
# The Strange History of Don't Ask, Don't Tell 3.9345455891000216
# Angels of Revolution 3.910324201058073
# The Man Who Came Back 3.898649729356742
# The Man of Gold 3.8803894570101516
# Paul Goodman Changed My Life 3.8754720978060786
# Το γάλα 3.8494141919681373
# Maria Chapdelaine 3.8019395866724244
# The Edge of the World 3.795625908357761
# Joni 3.7432565517320184
# War and Peace, Part IV: Pierre Bezukhov 3.7375831799944534
# Gold Coast 3.719418370677774
# Lucrezia Borgia 3.66738964475534
# Time Please 3.6649928674070704
# Aşk Kırmızı 3.6132841900474686
# Jails, Hospitals & Hip-Hop 3.5453542284187405
# Sundome 3.530644321242073
# Ill Gotten Gains 3.2389771826758493
#
#
# Movie: Captain Midnight
# User ID: 180120
# Suggested Movies and Predicted User Ratings:
#
# Choppertown: The Sinners 3.169111133817209
# Comrades in Arms 3.1441477610179867
# Frontier 3.121817749136264
# Walking Tall: The Payback 3.0825042015307402
# The Golden Bat 3.057296316519409
# Colossus of the Arena 3.0509535935545347
# The Trail of '98 3.046830455612254
# The World in His Arms 2.967212240881503
# Pirates of the 20th Century 2.8932526137472396
# The Thirteen Assassins 2.836792662406238
# Class of '61 2.826122308236124
# Kenau 2.777637651341419
# The Devil at 4 O'Clock 2.7134367889189503
# Toward the Terra 2.7123892830619365
# The Adventures of Tarzan 2.5933824496988893
# Albino 2.5420167929707778
# Password: Uccidete agente Gordon 2.507134008818701
# Assault of the Sasquatch 2.462283511716378
# Airspeed 2.460541837844607
# Reefer Madness 1.7123075192922734
#
#
# Movie: The BFG
# User ID: 245401
# Suggested Movies and Predicted User Ratings:
#
# Cirque du Soleil: Varekai 3.2981845430385106
# Puff, the Magic Dragon 3.0902673246021553
# The Fool of the World and the Flying Ship 3.048229453241536
# The Hunchedback Horse 3.0181882999494305
# Friend of the Jolly Devil 2.9132032127482677
# Princess Goldilocks 2.886197110125632
# VeggieTales: The Wonderful Wizard of Ha's 2.88427182742469
# Jill And Joy's Winter 2.8820126560747545
# Jason and the Argonauts 2.870838284069222
# The Magic Voyage of Sinbad 2.8447460674483613
# Night Gallery 2.8402852432930135
# E.T. the Extra-Terrestrial 2.7752085518777108
# The Adventurer: The Curse of the Midas Box 2.7192192578130387
# The Sword and the Dragon 2.7171533631803477
# Pete's Dragon 2.6983083680976745
# Epic 2.6883580939375
# Snow Queen 2.599209225495625
# The Indian in the Cupboard 2.37204236040658
# Playmobil: The Secret of Pirate Island 2.3519222972819023
# Return to Oz 2.2929077526287402
#
#
# Movie: Menace II Society
# User ID: 52523
# Suggested Movies and Predicted User Ratings:
#
# The Vanquished 3.73133863160083
# Sara 3.7133929300643227
# Samurai X : Reflection 3.5497668505091338
# Start Liquidation 3.5460325262334207
# Busting 3.4476666858465443
# Tell 3.38029153450657
# Set It Off 3.3646312526861313
# White Sands 3.3501344364242067
# Titli 3.3397510097666334
# Juice 3.335091037940428
# The Killing Machine 3.2916776817192885
# Silence the Witness 3.2861448164117752
# Ten Benny 3.2757844870263857
# Kiss of Death 3.2699062682164928
# Shiner 3.21486010714315
# Dead Presidents 3.2113035635666463
# Twelve 3.192447967936609
# Twisted 3.003068830113243
# Kite 2.6432653763878937
# Mitchell 1.7952360933437213
#
#
# Movie: Gringo: The Dangerous Life of John McAfee
# User ID: 165159
# Suggested Movies and Predicted User Ratings:
#
# After Tiller 4.07519395407296
# The Oath 4.046694907762361
# Life According to Sam 3.9720709496723523
# Sink or Swim 3.9483182741942238
# Garden Lovers 3.943820466263746
# American Teen 3.935612687938401
# The Price of Gold 3.9001086892014225
# Welcome to Australia 3.897646972022272
# These Birds Walk 3.862548352337325
# The Chinese Mayor 3.8077794247672836
# Paul Goodman Changed My Life 3.7723925620899306
# Vincent: A Life in Color 3.733766027796222
# Stevie 3.713604223583015
# Battle for Brooklyn 3.6383736022536732
# The Challenge... A Tribute to Modern Art 3.5565273354049123
# Life After Tomorrow 3.5501431307438907
# On the Ropes 3.546187956602542
# A Perfect Fake 3.534451599809439
# Girls Rock! 3.3151346813566924
# The Eyes of Tammy Faye 3.0634228956337815

# %%
hybrid_recommender(35, 'The Avengers')
# Out:
#                                                Title  Vote Count  \
# 41411                                       Serenity      1287.0
# 42206                                 Doctor Strange      5880.0
# 42262                                       Iron Man      8951.0
# 36165                                      Team Thor        93.0
# 32729          Marvel Studios: Assembling a Universe        44.0
# 42248                     Captain America: Civil War      7462.0
# 42272                                       Deadpool     11444.0
# 42216                                        Ant-Man      6029.0
# 42207            Captain America: The Winter Soldier      5881.0
# 42240                        Avengers: Age of Ultron      6908.0
# 36848                       Marvel One-Shot: Item 47       114.0
# 42243             Captain America: The First Avenger      7174.0
# 42241                                     Iron Man 2      6969.0
# 42235                                           Thor      6678.0
# 42263                                     Iron Man 3      8951.0
# 42001                            The Incredible Hulk      3086.0
# 42168                           Thor: The Dark World      4873.0
# 27752      Iron Man & Captain America: Heroes United        21.0
# 34903  Avengers Confidential: Black Widow & Punisher        68.0
# 33212                 Iron Man & Hulk: Heroes United        48.0
#
#        Vote Average      ID       est
# 41411           7.4   16320  4.361905
# 42206           7.1  284052  4.153873
# 42262           7.4    1726  4.126833
# 36165           7.5  413279  4.112717
# 32729           6.6  259910  4.099205
# 42248           7.1  271110  4.091808
# 42272           7.4  293660  4.054944
# 42216           7.0  102899  4.043048
# 42207           7.6  100402  3.992822
# 42240           7.3   99861  3.966149
# 36848           6.6  119569  3.920767
# 42243           6.6    1771  3.892130
# 42241           6.6   10138  3.747923
# 42235           6.6   10195  3.678164
# 42263           6.8   68721  3.662126
# 42001           6.1    1724  3.603179
# 42168           6.8   76338  3.560764
# 27752           5.8  284274  3.469509
# 34903           5.8  257346  3.275457
# 33212           5.4  230896  3.271672

# %%
hybrid_recommender(10, 'Mean Girls')
# Out:
#                                                    Title  Vote Count  \
# 31692  Puella Magi Madoka Magica the Movie Part III: ...        36.0
# 14299                                Live from New York!         5.0
# 34656                               Just One of the Guys        64.0
# 38215                                      Geek Charming       188.0
# 28333                                         Screwballs        22.0
# 35695                                          Frenemies        83.0
# 39125                              It's a Boy Girl Thing       279.0
# 37231                                             Zapped       131.0
# 41469                                           The DUFF      1372.0
# 35992                                  The Cheetah Girls        90.0
# 35099                          How to Build a Better Boy        71.0
# 39792                        Princess Protection Program       381.0
# 41234                               The Princess Diaries      1063.0
# 41069                                      Freaky Friday       919.0
# 38430                            I Love You, Beth Cooper       204.0
# 36564                                          Sleepover       105.0
# 41020                                            Beastly       878.0
# 35681                                     Barbie Diaries        83.0
# 40115            American Pie Presents: The Book of Love       454.0
# 39137                                       Mean Girls 2       281.0
#
#        Vote Average      ID       est
# 31692           7.3  212162  4.394826
# 14299           5.4  334328  3.755567
# 34656           6.4   24548  3.754710
# 38215           6.0   81250  3.725091
# 28333           4.7   25164  3.665975
# 35695           5.2   84105  3.548348
# 39125           6.3   37725  3.443764
# 37231           5.6  278774  3.432579
# 41469           6.8  272693  3.397726
# 35992           4.9   32293  3.391446
# 35099           5.7  286987  3.348946
# 39792           6.2   19458  3.341236
# 41234           6.5    9880  3.297944
# 41069           6.0   10330  3.262167
# 38430           5.2   19840  3.181469
# 36564           5.4    9893  3.007504
# 41020           5.9   38117  2.905606
# 35681           5.5   21705  2.898022
# 40115           5.1   26123  2.680548
# 39137           5.1   51481  2.313185

# %%
hybrid_recommender(35, 'Mean Girls')
# Out:
#                                                    Title  Vote Count  \
# 31692  Puella Magi Madoka Magica the Movie Part III: ...        36.0
# 14299                                Live from New York!         5.0
# 35695                                          Frenemies        83.0
# 39125                              It's a Boy Girl Thing       279.0
# 34656                               Just One of the Guys        64.0
# 38215                                      Geek Charming       188.0
# 35099                          How to Build a Better Boy        71.0
# 28333                                         Screwballs        22.0
# 37231                                             Zapped       131.0
# 41469                                           The DUFF      1372.0
# 41069                                      Freaky Friday       919.0
# 41234                               The Princess Diaries      1063.0
# 35992                                  The Cheetah Girls        90.0
# 39792                        Princess Protection Program       381.0
# 35681                                     Barbie Diaries        83.0
# 38430                            I Love You, Beth Cooper       204.0
# 36564                                          Sleepover       105.0
# 41020                                            Beastly       878.0
# 39137                                       Mean Girls 2       281.0
# 40115            American Pie Presents: The Book of Love       454.0
#
#        Vote Average      ID       est
# 31692           7.3  212162  4.404914
# 14299           5.4  334328  3.952208
# 35695           5.2   84105  3.521542
# 39125           6.3   37725  3.472875
# 34656           6.4   24548  3.401603
# 38215           6.0   81250  3.387064
# 35099           5.7  286987  3.364189
# 28333           4.7   25164  3.328902
# 37231           5.6  278774  3.312382
# 41469           6.8  272693  3.311737
# 41069           6.0   10330  3.238174
# 41234           6.5    9880  3.169254
# 35992           4.9   32293  3.118925
# 39792           6.2   19458  3.114169
# 35681           5.5   21705  3.025963
# 38430           5.2   19840  2.991909
# 36564           5.4    9893  2.938378
# 41020           5.9   38117  2.822588
# 39137           5.1   51481  2.448561
# 40115           5.1   26123  2.403273
